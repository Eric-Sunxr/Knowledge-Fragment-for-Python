# %% [markdown]
# ## 「GoPUP」，大佬造的轮子，大概有100+的免费数据接口。
#
# 使用文档：http://doc.gopup.cn/#/README
#
# 主要有指数数据、宏观经济数据、新经济数据、微博KOL数据、信息数据、生活数据、疫情数据等。

# %%
#安装
# !pip install gopup --upgrade
# Out:
# ...
#   Created wheel for demjson: filename=demjson-2.2.4-py3-none-any.whl size=73548 sha256=24d6e73296f67d0d57b1ce1323bf8844931d310f890a375e601655871c57ec2c
#   Stored in directory: c:\users\eric\appdata\local\pip\cache\wheels\41\94\3d\466801f4a8db8e6fce765d7a0115dfebcc55ddf6b00cd98f59
# ...
#   Created wheel for pyexecjs: filename=PyExecJS-1.5.1-py3-none-any.whl size=14593 sha256=17c6eed0fde078b5e468a52bb2859ba5f2886960bf271e1dbe78b8b0cced24a4
#   Stored in directory: c:\users\eric\appdata\local\pip\cache\wheels\9a\ee\03\da5c0b4a8c13362beeb844eb913bbe58a89bde1de2b9157007
# ...
#   Created wheel for jsonpath: filename=jsonpath-0.82-py3-none-any.whl size=5618 sha256=1079eaed383882ebd92d4e81471b8c22f502c446a496219fbaa06a6b0a6d5c30
#   Stored in directory: c:\users\eric\appdata\local\pip\cache\wheels\93\96\be\f88ab62b037a115c856324fd87a04b97807069a229560add06
# Successfully built demjson pyexecjs jsonpath
# ...

# %% [markdown]
# ### 01 微博指数
#
# 获取指定关键词的微博指数。

# %%
import gopup as gp
df_index=gp.weibo_index(word="马保国",time_type="1month")
# time_type="1month"; 1hour, 1day, 1month, 3month 选其一。
df_index
# Out:
#                 马保国
# index
# 2020-11-10     7507
# 2020-11-11    21181
# 2020-11-12    57131
# 2020-11-13    49884
# 2020-11-14    45097
# 2020-11-15  1086803
# 2020-11-16    95659
# 2020-11-17   321736
# 2020-11-18   419387
# 2020-11-19   146335
# 2020-11-20   268914
# 2020-11-21   142264
# 2020-11-22   318461
# 2020-11-23   295281
# 2020-11-24   861445
# 2020-11-25   385294
# 2020-11-26   108010
# 2020-11-27    90687
# 2020-11-28   581430
# 2020-11-29   199956
# 2020-11-30    43668
# 2020-12-01    42822
# 2020-12-02    22060
# 2020-12-03    16095
# 2020-12-04     9765
# 2020-12-05     9914
# 2020-12-06     5298
# 2020-12-07    18552
# 2020-12-08     2962
# 2020-12-09     3599
# 2020-12-10     5725

# %% [markdown]
# ### 02 百度指数
#
# 获取指定关键词的百度搜索指数。

# %%
import gopup as gp
import gopup as gp
# cookie = "此处输入您在网页端登录百度指数后的 cookie 数据"
cookie='CHKFORREG=49ac45de5371f5446c632a41ee901db5; BIDUPSID=2F305FDE58908E98E2012F04E8237293; PSTM=1605098510; BAIDUID=2F305FDE58908E9848EA026F022C92E3:FG=1; BDUSS=JTeG56dHd-VHkwMDdwMUFQa1VCMllPUTAyTDhCSHdMQjA4NTczc1BuQWl-OVZmRVFBQUFBJCQAAAAAAAAAAAEAAACCv7nERXJpY8vvy-8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAACJyrl8icq5fcz; BDUSS_BFESS=JTeG56dHd-VHkwMDdwMUFQa1VCMllPUTAyTDhCSHdMQjA4NTczc1BuQWl-OVZmRVFBQUFBJCQAAAAAAAAAAAEAAACCv7nERXJpY8vvy-8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAACJyrl8icq5fcz; delPer=0; BAIDUID_BFESS=2F305FDE58908E9848EA026F022C92E3:FG=1; PSINO=1; H_PS_PSSID=1426_33076_33061_31660_32970_33099_33100_32845_33199_33239_33149_33265; BDSFRCVID=DiKOJexroG3SQbJrFgslFroCtrpWxY5TDYLEOwXPsp3LGJLVJeC6EG0Pts1-dEu-EHtdogKK0gOTH6KF_2uxOjjg8UtVJeC6EG0Ptf8g0M5; BCLID=9231279532187687702; H_BDCLCKID_SF=tR3aQ5rtKRTffjrnhPF3Q-FUXP6-hnjy3b7gbRoF-qQJqnRDK4nT5bDQ3p7ktl3RymJ42-39LPO2hpRjyxv4y4Ldj4oxJpOJ-bCL0p5aHl51fbbvbURvD--g3-AqBM5dtjTO2bc_5KnlfMQ_bf--QfbQ0hOhqP-jBRIEoCvt-5rDHJTg5DTjhPrMQMriWMT-MTryKKORLRokqlQTKPvPK44d5h5jLbvkJGnRhlRNB-3iV-OxDUvnyxAZyxomtfQxtNRJQKDE5p5hKq5S5-OobUPUDMJ9LUkqW2cdot5yBbc8eIna5hjkbfJBQttjQn3hfIkj2CKLK-oj-DDRj50M3e; BA_HECTOR=8180248h21210h012n1ft6bd30q; Hm_lvt_d101ea4d2a5c67dab98251f0b5de24dc=1607675302; bdindexid=9hii8ks4kf1qkve1m012ragvu2; RT="z=1&dm=baidu.com&si=nkgmuvb6whf&ss=kik0d547&sl=2&tt=1wq&bcn=https%3A%2F%2Ffclog.baidu.com%2Flog%2Fweirwood%3Ftype%3Dperf&ul=isu"; Hm_lpvt_d101ea4d2a5c67dab98251f0b5de24dc=1607675325'
index_df = gp.baidu_search_index(word="马保国", start_date='2020-11-15', end_date='2020-11-25', cookie=cookie)
index_df
# Out:
#                马保国
# date
# 2020-11-15  133241
# 2020-11-16  141167
# 2020-11-17  139804
# 2020-11-18  145732
# 2020-11-19  140943
# 2020-11-20  151124
# 2020-11-21  155980
# 2020-11-22  167966
# 2020-11-23  170219
# 2020-11-24  190611
# 2020-11-25  162825

# %% [markdown]
# ### 03 头条指数

# %%
import gopup as gp
index_df = gp.toutiao_index(keyword="马保国", start_date='20201115', end_date='20201125')
index_df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-8-3317448ce3db> in <module>
#       1 import gopup as gp
# ----> 2 index_df = gp.toutiao_index(keyword="马保国", start_date='20201115', end_date='20201125')
#       3 index_df
#
# F:\Anaconda\lib\site-packages\gopup\index\index_toutiao.py in toutiao_index(keyword, start_date, end_date)
#      31     }
#      32     res = requests.get(url, params=data, headers=index_toutiao_headers)
# ---> 33     hot_list = json.loads(res.text)['data']['hot_list'][0]['hot_list']
#      34     df = pd.DataFrame(hot_list)
#      35     return df
#
# F:\Anaconda\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# ...
