# %% [markdown]
# # simpletransformers
# 使用pip install simpletransformers命令
# 使用之前，最好更新一下transformers库，因为这个simple版本相当于给transformers库进行再封装。
# ### 使得高级预训练模型（BERT、RoBERTa、XLNet、XLM、DistilBERT、ALBERT、CamemBERT、XLM-RoBERTa、FlauBERT）的训练、评估和预测变得简单，每条只需3行即可初始化模型。当前支持序列分类（二进制，多类，多标签，句子对），序列标注（NER）、问答、回归、会话式AI和多模态任务。该库主要基于Hugging Face 的Transformer库。

# %% [markdown]
# 这里的数据集在可以下载到：https://www.kesci.com/home/dataset/5e7a0d6398d4a8002d2cd201/files
#
# 预训练模型在：
#
# https://huggingface.co/models

# %%
from simpletransformers.classification import ClassificationModel
import pandas as pd
import smart_open
import numpy as np 
from sklearn import preprocessing

# %%
#载入数据
data1 = open(r'data\muti_class1776\train_data.word.ed',encoding='utf-8').readlines()
data2 = open(r'data\muti_class1776\val_data.word.ed',encoding='utf-8').readlines()
# len(data1),len(data2)
data1
# Out:
# ['society\\t陆家嘴 不 雅 视频 曝光 ： 系恶 “ 性 ” 营销 ？\n',
#  'world\\t日本 冲绳 民众 举行 大规模 抗美 集会 活动 冲绳 县知事 : 希望 改变 政治 结构\n',
#  'entertainment\\t林心如 全黑 连体 装 现身 ， 被 赞比 模特 身材 更好\n',
#  'car\\t别克 逆 生长 实验 型\n',
#  'baby\\t你 的 宝宝 到底 需不需要 补锌 ？ 又 该 如何 补充 ？ （ 内附 补锌 食谱 ）\n',
#  'sports\\t名记 为 快船 支招 ： 格里芬 换 小将 再 签 KD\n',
#  'tech\\t装逼 课堂 丨 如何 快速 加微信 好友 加 到 爆机\n',
#  'society\\t山西 ： 安全带 保 安全 （ 一 ） — — 不系 安全带 事故 酿 大祸\n',
#  'military\\t陆空 对抗 ， 友邻 互为 “ 磨刀石 ”\n',
#  'entertainment\\ttvN 推 全新 综艺 《 Babel250 》 外国人 组团 创新 语言\n',
#  'entertainment\\t“ 中国 男团 ” 征战 欧洲 秀场 胡歌 爆发 时尚 力\n',
#  'tech\\t微软 梁戈 碧 ： 微软 用 实际行动 爱 Linux\n',
#  'sports\\t英格兰 的 上限 有 多 高 ？ 真核 浮现 最大 X 因素 就是 他\n',
#  'finance\\t同洲 电子 ： 袁明 辞职 承诺 6 个 月 内 不 办理 股权 转让\n',
#  'story\\t讽刺 故事 ： 喷嚏\n',
#  'society\\t中环 高架桥 路面 受损 肇事 车辆 行驶 路径 已 查明\n',
#  'sports\\t宁泽涛 参加 里 约 奥运 峰回路转\n',
#  'car\\t百万 宝马 + 001 牛牌 被 弃 停车场 ！ 想 去 开 回来 却 交不起 停车费 ！\n',
#  'game\\t娱乐 卡组 推荐 ： 小明术\n',
#  'society\\t先 结婚 再 办房 房子 凭 啥 不是 夫妻 共有 财产 ？\n',
#  'world\\t俄媒 : 美越 关系 亲近 或 损害 俄中 在 东南亚 的 利益\n',
#  'car\\t交通部 要 使出 绝杀 了 ！ Out 吧 ， 飞机 板 ！\n',
#  'car\\t自主 硬派 SUV 来 了 ， 到底 谁 才 是 真正 “ 硬汉 ”\n',
#  'car\\t深挖 秘闻 得知 2018 年 将 有 新 皮卡\n',
#  'car\\t舒淇 、 金秀贤 等 九大 人气 明星 代言 的 轿车\n',
#  'entertainment\\t孙红雷 携 妻子 出席 迪士尼 活动 颜王 夫妇 再秀 恩爱\n',
#  'finance\\t新 三板 创新 层 最终 名单 出炉 九鼎 集团 自愿 退出\n',
#  'world\\t澳洲 外海 再 发生 鲨鱼 攻击 事件 女 潜水 客 遇袭 丧命\n',
#  'tech\\t李斌 谈 新能源 汽车 ： 续航 问题 还 可 优化 500 公里 将 是 标配\n',
#  'entertainment\\t范冰冰 张柏芝 舒淇 夜店 寻欢作乐 照片 曝光 ， 每张 都 好 劲 爆 ， 炒鸡辣 ！\n',
#  'finance\\t定增 成为 最 主流 的 手段 你 买 基金 有没有 选 这种 类型 ？\n',
#  'tech\\t谷歌 携手 LG 推出 一款 智能 手表 挥挥手 就 能 操作\n',
#  'world\\t台海 政经 ： 菲新 总统 或 最快 九月 访华 分析 称 亚太地区 安全 将 趋稳\n',
#  'history\\t徐达 真的 是 被 朱元璋 赐 蒸鹅 害死 的 吗 ？\n',
#  'society\\t贵州 农村 青壮年 多渠道 学 技能 今年 将 培训 30 万人 以上\n',
#  'sports\\t阿根廷 发布会 智利 记者 挑事 被 揭穿 马 蒂诺 幽默 应对\n',
#  'car\\t汽车空调 不当 使用 会 要命 ？ 这是 真的 ！\n',
#  'sports\\t第 10 次 参斯杯 周鹏 追忆 时光 老 熟人 迪奥 古 示弱\n',
#  'sports\\t埃神 ： 孔卡 指引 我 来到 上港 金靴 之争 看好 阿兰\n',
#  'society\\t泰安 ： 打 疫苗 后 昏迷 ， 6 岁 女童 昏迷 7 天后 不治 身亡\n',
#  'sports\\t小将 王潼 美国 特训 上演 隔人 补扣\n',
#  'entertainment\\t黄毅 清 ： 公开 私密 聊天记录 难 容忍 ！ 网友 ： 那 黄奕 被 曝 那些 事 怎么 说\n',
#  'society\\t打工者 的 未来 不是 梦 ！\n',
#  'sports\\t新疆 总经理 ： 周琦 去不去 NBA 等 奥运 后 再定\n',
#  'tech\\t1699 元 ！ DOBBY 无人机 来 了 ： 可 放入 口袋\n',
#  'tech\\t小米 5 管够 ， 是 小米 5 产能 充足 还是 小米 5 卖不动 了 ？\n',
#  'military\\t伤亡惨重 的 抗美援朝 ， 你 知道 多少 ？\n',
#  'finance\\t“ 留英 女博士 ” 代 人 炒股 虚实 难辨 遭 “ 姐妹 ” 起诉\n',
#  'sports\\t新星 未来 无极限 ！ 张玉宁 国足 首秀 梅开二度\n',
#  'tech\\t小米 三指 下拉截 屏 功能 周五 登陆 MIUI8 开发 版\n',
#  'game\\t《 钢铁 雄心 4 》 部队 作战 阶段 效果 详细 解析\n',
#  'tech\\t《 天天向上 》 介绍 的 无人机 HOVERCAMERA 值得 入手 吗 ？\n',
#  'entertainment\\t“ 世界 小姐 ” 张梓琳 与 陈妍希 邓紫棋 同框 ， 短腿 无尽 的 尴尬\n',
#  'society\\t自己 的 难处 ， 只有 自己 才能 懂 ！\n',
#  'entertainment\\t90 版 《 封神榜 》 武王近 照曝光 56 岁 依旧 风流倜傥\n',
#  'car\\t这 是 场 510 匹 与 1750 匹 马力 的 战争\n',
#  'society\\t西昌 交通 学校 校长 赫 天华 涉嫌 受贿 被 立案侦查\n',
#  'world\\t美国 人民 太 豪放 平均 十天 闯 一次 机场 围栏\n',
#  'world\\t普京 军事 大 总管 给 中国 一 重磅 装备 ， 气疯 五角大楼\n',
#  'entertainment\\tTFBOYS 王俊凯 秒 变 北京 瘫大长 腿 华丽 抢镜\n',
#  'entertainment\\t《 购物 王路易 》 主演 阵容 确定 徐仁国 尹相铉 等 主演\n',
#  'world\\t毛里求斯 再次 发现 疑似 MH370 客机 残骸\n',
#  'society\\t南航 一空少 撞 脸 宋仲基 ！ 论 被 老公 服务 是 种 什么样 滴 体验\n',
#  'finance\\t谨防 明日 稍大些 震荡 回调\n',
#  'game\\t《 3D 定制 女仆 》 迎 B 版 VR 更新 双 控制器 实测 体验\n',
#  'society\\t综述 ： 泰国 “ 救虎 ” 行动 全部 完成 ２ ２ 人 被诉 走私 野生动物\n',
#  'finance\\t16 日测 大盘 ： 放量 预示 着 今日 继续 涨\n',
#  'society\\t疑似 真凶 王书金 ： 活在 “ 聂树斌案 ” 里 的 11 年\n',
#  'sports\\t国安 换帅 换来 团结 回 正轨 二次 转会 将 迎新 外援\n',
#  'military\\t答 好 改革 这张 “ 考卷 ”\n',
#  'car\\t为什么 要用 推 背感 推走车 窗外 的 那段 旅途\n',
#  'finance\\t四川 路桥 建设 集团股份 有限公司 2016 年 4 、 5 月 重大 工程 中标 公告\n',
#  'car\\t看 内饰 这车值 一百万 ， 哈弗 最新款 搭配 全新 电子 档杆 诚意 十足\n',
#  'sports\\t莫蒂埃 尤纳斯 与 德 安东尼 共 进晚餐\n',
#  'world\\t英国 宣布 脱离 欧盟 和 我们 农民 有 关系 吗 ？\n',
#  'car\\t遇到 朋友 借车 ， 你 会 怎么 做 ？\n',
#  'game\\t《 汤姆 克兰西 ： 全境 封锁 》 无垠 天际 组队 打法 技巧 解析 攻略\n',
#  'tech\\t在 VR 红海 创业 ， 这位 前谷歌 眼镜 工程师 说 “ 机会 在于 核心 技术壁垒 ”\n',
#  'car\\t治愈 你 的 良药 体验 新 宝马 7 系 手势 识别 黑 科技\n',
#  'fashion\\t聚拢 内衣 ， 让 女人 更 性感 ！\n',
#  'discovery\\t中国 有望 取得 重大突破 未来 科技 或 由 国人 领衔\n',
#  'world\\t日本 的 捕鲸 活动\n',
#  'car\\t别错过 ！ 分秒 教会 你 开 兰博基尼 所有 车型\n',
#  'world\\t“ 伊斯兰 国 ” 的 政治 自杀 ？\n',
#  'entertainment\\t何炅忙 着 投资 公司 ， 哪 有空 主持 新 节目\n',
#  'society\\t今日 看点 ： 养老保险 为 我们 的 社会 发挥 着 积极 的 作用\n',
#  'travel\\t夏季 在 札幌 体验 自然 与 味觉 的 精妙\n',
#  'entertainment\\twuli 朴 宝剑 今日 破蛋 日 和 妹子 的 最甜 cp 却 下车 了\n',
#  'society\\t川南 城际 铁路 快马加鞭 内自 泸线 先期 施工 段 6 月 开工\n',
#  'baby\\t妈妈 放松 的 心态 ， 真能 带给 孩子 无穷的 心理 力量 ！\n',
#  'sports\\t这才 是 孙悦 这位 国内 攻防 最好 外线 球员 得不到 宫鲁鸣 赏识 的 真正 原因\n',
#  'society\\t德国 进口 “ 防洪 神器 ” 将 在 浙江 余姚 上岗 ， 用于 姚江 防洪\n',
#  'sports\\t皮蓬 妻子 南 海滩 游玩 粉色 比基尼 身材 火辣\n',
#  'finance\\t测评 | 从 鲨鱼 经济学 看 ， 买 保险 到底 值不值 ？\n',
#  'sports\\t恨铁不成钢 — — 论 刘诗雯 落选 奥运 单打 之 必然性\n',
#  'car\\t梅赛德斯 - 迈巴赫 E 级 现身 国内\n',
#  'car\\t画风 清奇 的 甲壳虫 改装 风格\n',
#  'regimen\\t有 良知 的 医生 是 不会 随便 给 人 做 这项 牙齿 手术 的 ！ 看 完 你 就 明白 了 930 新闻 眼\n',
#  'game\\t《 王者 荣耀 》 刘婵 成倍 增强 刘邦 却 被 削 得 生活 无法 自理\n',
#  'history\\t她 是 最早 的 女 游击队员 ， 说 了 一番话 后 ， 竟 被 日军 挖去 双眼 和 心脏\n',
#  'sports\\t韩 官方 仍 拒朴 泰桓战里 约 称 禁止 运动员 打 感情 牌\n',
#  'game\\tXplay5 日 销售额 达 一亿 ， 并 不 只有 双曲 屏 那么 简单 ！\n',
#  'car\\t神龙 “ 中考 ” 只得 75 分 ， 东标 降幅 较大\n',
#  'car\\t重卡玩起 了 创意 ， 奥迪 花 重金 打造 创意 重卡 ， 太牛 了\n',
#  'car\\t最 尴尬 的 遇见 ， 宾利 与 保时捷 车主 面面相觑 ， 掉头就走\n',
#  'finance\\t谭浩俊 ： 宝能 “ 入侵 ” 万科 至少 有 四大 贡献\n',
#  'sports\\t四国 女篮 争霸赛 嘉禾 落幕 中国女篮 3 战全胜 夺冠\n',
#  'society\\t知道 空姐 的 休息室 是 什么 样子 的 吗 ？\n',
#  'car\\t10 万提 走 ！ 这 车 确实 便宜 又 好 用 ， 但 这 外观 真是 不想 吐槽 ！\n',
#  'society\\t2016 / 6 / 21 ( 487 ) 大快人心 ！ 安陆 10 名 “ 1040 阳光工程 ” “ 老总 ” 获刑\n',
#  'sports\\t太 刺激 了 ！ 德国 球迷 点球 大战 获胜 后 疯狂 庆祝\n',
#  'baby\\t警惕 ！ 十大 “ 恶劣 ” 行为 打击 孩子 自信\n',
#  'society\\t市 公交 总公司 ： 车辆 干净 整洁 司机 文明 驾驶\n',
#  'car\\t插电 混动 车型 下线 BMWX1 即将 上市\n',
#  'tech\\t西门子 利用 SLM 技术 提升 涡轮机 叶片 制造 效率\n',
#  'tech\\tiOS9Spotlight 搜索 建议 新增 7 个 地区 支持\n',
#  'finance\\t你们 都 错 了 ！ 海底 捞 成功 的 真正 秘诀 并 不是 “ 变态 服务 ”\n',
#  'baby\\t怀孕 后 内脏 被 挤 到哪去 了 ? 看 完 我 落泪 了 ！\n',
#  'game\\t《 魔兽 》 ： 可能 要 拍成 一部 连续剧 ！ 除了 情怀 ， 它 还有 什么 ？\n',
#  'fashion\\t“ 最炫晶 女郎 ” 胡然 曝 写真 大片 红唇 黑纱 尽显 魅惑\n',
#  'travel\\t山西 晋城 你 永远 不 知道 的 那件事\n',
#  'game\\t小 编要 去 直播 了 ， 你们 看不看 ？ ｜ 车来 了\n',
#  'food\\t夏天 这么 热 ， 不想 吃饭 怎么办 ？ 那 就 烙个 饼 呗 ！\n',
#  'world\\t莫斯科 举行 新娘 游行 ， 美娇娘 争奇斗艳\n',
#  'world\\t这个 亚洲 大国 不 简单 ， 美日 手段 用尽 却 懊恼 摸不透 他 底牌\n',
#  'sports\\t克劳福德 对 快船 的 报价 很 失望 ？\n',
#  'entertainment\\t都 是 二胎 惹 的 祸 ！ 老公 被 弄 得 半死不活 ， 让 涂磊 一番 毒舌 给 整活 了 ！\n',
#  'history\\t宋庆龄 晚年 想见 小妹 一面 ， 宋美龄 知道 后 冷冷 回复 ， 事后 又 独自 流泪\n',
#  'finance\\t新 三板 有望 重启 类 金融 企业 挂牌 准入 标准 不再 一刀切\n',
#  'society\\t微信 交友 被 骗财骗色 女子 逛街 认出 嫌疑人\n',
#  'tech\\t如何 构建 公司 财务管理 团队 ？\n',
#  'tech\\t自晒 出萌娃 “ 蜜桃 臀 ” 后 再也 无法 正视 蜜桃 了\n',
#  'entertainment\\t表情 包界 年龄 最小 的 颜艺帝 泰 吴 宝宝 ， 要 暂时 离开 我们 了\n',
#  'car\\t平行 进口 美规 奔驰 GL450 比中规 4S店 奔驰 差 吗 NO\n',
#  'car\\t夜晚 效果 太酷 炫 了 长城 炫丽 加装 车 内 氛围 灯\n',
#  'game\\t王思聪 骂 女主播 网红代 打 遭 喷 剧情 可谓 一波三折\n',
#  'tech\\tMAC 电脑 有 必要 安装 windows 系统 吗 ？\n',
#  'game\\t盘点 30 年 ， 6 对 有 父子关系 的 玩具 与 游戏 ， 从 80 后 玩 到 10 后\n',
#  'society\\t小 夫妻 创业 经 ： 像 蚯蚓 一样 “ 拱 ” 出 创业 路\n',
#  'travel\\t号称 东方 四大 奇迹 ， 不过 7 米 高墙 的 吴哥 古迹 缘何 能够 比肩 长城\n',
#  'military\\t乌克兰 寻求 加入 北约 ， 中国空军 难 接收 安 - 225\n',
#  'car\\t你 绝对 想不到 ： 古巴 街头 卡车 品牌 竟然 是 这些 | 卡车 之友 网\n',
#  'tech\\t研究 显示 拍照 让 人类 更加 快乐\n',
#  'history\\t她 是 公主 ， 却 指使 刺客 谋杀 亲父 ， 最终 落 了 个 活活 被 自己 气死 的 下场\n',
#  'car\\t中国 10 大 汽车品牌 ， 哈弗仅 排 第 8 ， 这个 品牌 当属 第 1 ！\n',
#  'tech\\tIDC 指出 ， NetApp 在 全 闪存 市场 上 位列 第二\n',
#  'entertainment\\t天娱 艺人 都 逃不过 整容 命 ， 华晨 宇 你 还 认得 出来 吗 ？\n',
#  'game\\t「 游戏 教科书 」 第六期 一场 赌上 男人 尊严 的 战斗\n',
#  'sports\\t梅州 队 主场 塑胶跑道 已经 晒 软 了 ， 但 卡纳瓦罗 并 不当 回事儿\n',
#  'entertainment\\t还 记得 「 凤姐 」 吗 ？ 如今 人生 大 不同 真 风光 了\n',
#  'society\\t汽车 居然 也 能 被 烤化 这 意大利 的 太阳 太毒 了\n',
#  'sports\\t李根 女友 晒 合照 秀 恩爱 ： 每天 我们 都 幸福 甜蜜\n',
#  'sports\\t帅 哭 了 ！ 当 足球 运动员 换上 正装\n',
#  'fashion\\t身材 好 的 美女 千万别 乱 穿衣 会 很 难堪 又 拉 低 档次\n',
#  'car\\t美系 小型 SUV 选 自由 侠 还是 新昂 科拉 ？\n',
#  'finance\\t石油 国 “ 泥菩萨过江 ” ， 去 美元 化 呼声 日渐 高涨 ， 人民币 将 取代\n',
#  'sports\\t意媒 ： 罗马 1000 万欧 求购 维尔 马伦\n',
#  'tech\\t请 Twitter 前 CEO 打下手 ， 热播 美剧 《 硅谷 》 为了 追求 真实 也 是 没 谁 了\n',
#  'game\\tPdd 反向 抽烟 只排 第二 ？ 盘点 LOL 职业 选手 的 逆天 操作 gif\n',
#  'finance\\t重大 事项 停牌 进展 公告\n',
#  'baby\\t怀孕 啦 ， 经常 喝牛奶 和 豆浆 的 孕妈 ， 区别 竟然 这么 大\n',
#  'car\\t全球 最贵 洗 车工 洗 一次 竟达 5 万元\n',
#  'society\\t泰国 厕所 再 惊魂 ！ 男子 下体 被 蟒蛇 咬伤 失血过多 昏倒 送医\n',
#  'tech\\t6 月 28 日 互动 平台 11 家 公司 透露 利好\n',
#  'society\\t湖南 首例 汽车 “ 退一 赔 三 ” 案 ： 13 万 买辆 旧车 获赔 三辆 新车\n',
#  'society\\t毁 三观 ！ 妻子 产 健康 男婴 丈夫 竟满 医院 寻求 换 女婴\n',
#  'world\\t欧洲 第一 活火山 ， 埃特纳 火山 再度 喷发 ， 烟柱 冲天 蔚为壮观\n',
#  'car\\t最怕 起 错名 盘点 六款 名字 最绕 口 的 合资 车\n',
#  'car\\t选车 时 这些 配置 要 了 吗 ？ 要 了 您 就 上当 了\n',
#  'travel\\t火车 上 偷拍 到 的 朝鲜 、 印度 火车 餐 ， 居然 比 中国 的 要 丰盛 ？\n',
#  'car\\t都 说 SUV 油耗 高 ， 这 10 款卖 的 最好 的 自主 品牌 SUV 油耗 是 多少\n',
#  'essay\\t唯美 的 句子 说 说 心情 最新版 的\n',
#  'game\\t《 巫师 3 》 血 与 酒 熊派 与 猫 派 玩法 心得 分享\n',
#  'sports\\t深陷 泥潭 ， 我们 给鲁能 支 支招\n',
#  'world\\t美媒 : 全球 各国 政府 都 在 改变 签证 规定 以 欢迎 中国 游客\n',
#  'car\\t新能源 汽车 产业链 发展前景 展望\n',
#  'sports\\t各有 各 的 美 ， NBA 最美 队嫂 大盘 点 ， 一人 竟是 联盟 共有 ！\n',
#  'finance\\t长城 动漫 清仓 焦炭 产业 逾 7 亿 收购 VR 公司\n',
#  'entertainment\\t综艺 首秀好 青涩 ！ 窦靖童 综艺 配合 度狂 甩 王菲\n',
#  'finance\\t公告 隐现 重大 利好 周四 6 股 有望 突破 大涨\n',
#  'military\\t太强大 ！ 一旦 此 工程 完成 ， 中国 将 重回 世界 军事 顶端 ！\n',
#  'world\\t加拿大 第一例 手臂 移植 患者 康复 状况良好\n',
#  'entertainment\\t这女 的 身材 那么 好 ， 样子 也 不错 ， 但 她 男友 却 受不了\n',
#  'sports\\t曝 巴萨 圈定 4 星 补强 一 短板 横刀夺爱 抢 皇马 意中人\n',
#  'entertainment\\t张亮 曝雅痞 时尚 写真 花 西装 尽显 型 男 魅力\n',
#  'society\\t上 撞 法拉利 ， 下撞 劳斯莱斯 ， 这辆 大 面包车 悲剧 了 ！\n',
#  'entertainment\\t好看 的 高干 小说 （ 含 点评 ）\n',
#  'history\\t军统 第一 杀手 — — 陈恭澍 ｜ 21 : 10 《 风雨飘摇 话 军统 》\n',
#  'game\\tlol 文森特 开挂 事件 真正 原因 高端 局 的 内幕\n',
#  'car\\t落地 不到 15 万 续航 近 400km 试驾 比亚迪 秦 EV300\n',
#  'sports\\t库里 和 小朋友 一对一 竟 毫无 违和感\n',
#  'tech\\t打印机 都 是 傻 大 笨 粗 ？ 报告 ， 这里 有 一款 高颜值 的 ！\n',
#  'tech\\t马化腾 砸 100 亿 推微信 “ 微粒 贷 ” 让 个人 信贷 无需 抵押 ！\n',
#  'sports\\t里 约 奥运 单打 咫尺天涯 ， 刘诗雯 许昕 还有 戏 吗 ？\n',
#  'game\\t《 符石 守护者 》 iOS 版 限时 免费 两天 快 来 体验 国人 神作 ！\n',
#  'world\\t以色列 特拉维夫 发生 严重 枪击 事件\n',
#  'history\\t他 叔父 是 康熙 重臣 ， 姐姐 是 乾隆 皇后 ， 他 自己 是 一代 名臣\n',
#  'entertainment\\t李连杰 近况 堪忧 ， 瘫痪 面临 ， 其 54 岁 妻子 身材 依旧 火辣\n',
#  'sports\\t詹姆斯 告诉 库里 谁 才 是 联盟 第一 人 ， 同时 被 欧文 彻底 打爆\n',
#  'sports\\t占卜师 预测 林李 大战 脱口而出 李宗伟 将 胜出\n',
#  'entertainment\\t方力申 称 今年 犯 太岁 家人 生病 自己 分手\n',
#  'game\\t冲击 总冠军 王者 荣耀 暑期 盛典 将 迎 巅峰 之战\n',
#  'society\\t周滨案 宣判 周永康 案中 人 都 判 了 几年 ？\n',
#  'car\\t性价比 超高 的 迈巴赫 S400 半年 使用 感受\n',
#  'tech\\t在 哪些 加油站 加油 可以 使用 支付宝 ？\n',
#  'travel\\t世界 上 最 香艳 的 裸体 海滩 ， 目不暇接 美不胜收 ！\n',
#  'entertainment\\t在 王思聪 微博下 喊 老公 的 女人 到底 是 什么 心理 ？\n',
#  'food\\t娶 了 个 土豪 媳妇 ， 做 了 一 大锅 龙虾 ， 我 不得不 夸 她 ， 做 的 真 好 ！\n',
#  'tech\\t8 种 职业 即将 消失 ， 这 其中 有 你 吗 ？\n',
#  'game\\tSupercell 、 King 反压 MZ 一头\n',
#  'entertainment\\t小贝 带俩 儿子 观 温网 搂 肩热聊 父爱 浓\n',
#  'sports\\tC 罗 拒绝 和 冰岛 球员 握手 真相 竟然 和 报道 的 不 一样\n',
#  'car\\t开车 走神 ， 直接 撞 向 我车\n',
#  'sports\\t我 的 外婆 是 灵媒 ， 她 却 给 我配 了 冥婚 ， 让 我 娶 女鬼 做 妻子 2\n',
#  'sports\\t纪念 高球赛 再现 新 冠军 37 岁麦 格特 获美 巡首冠\n',
#  'society\\t孕妇 罕见 宫内 宫外 同时 怀孕 致 腹腔 出血 3000 毫升 险 丧命\n',
#  'sports\\t象棋 高手 必修课程 — 每天 学点 古谱 （ 12 ）\n',
#  'tech\\t《 魔兽 》 2 天 票房 6 亿 ， 腾讯 影业 这个 “ 新兵 ” 做 了 哪些 事 ？\n',
#  'world\\t普京 访华 中国 送 俄 巨额 军售 大单 西方 打击 俄罗斯 计划 彻底 落空\n',
#  'entertainment\\t61 岁 赵雅芝 竟然 要 上 真人秀 ， 小 三 上位 的 她 如何 变成 全民 女神 的 ？\n',
#  'tech\\t互联网 ， 无法挽救 下滑 的 中国 经济\n',
#  'tech\\t宽带 提速 后 ， 上网 反而 感觉 变慢 了 ？ 或许 这 就是 原因 ！\n',
#  'tech\\t大 数据 ： 依赖 倒置 、 控制 反转 、 依赖 注入 、 面向 接口 编程 \u200b\n',
#  'entertainment\\t还 记得 创造 中国 模特 界 多个 第一 的 超模 马艳丽 吗 ？\n',
#  'world\\t不满 薪资 与 教学 环境 英国 教师 工会 支持 罢工\n',
#  'world\\t普京 拒 就 英国 “ 脱欧 ” 发表 己见 日媒 : 一旦 “ 脱欧 ” 影响 欧美 对 俄 包围\n',
#  'sports\\t巴萨 助 西班牙 赢球 ， 意大利 2 : 0 逆袭 ！ 欧洲杯 看 C 罗 美洲杯 看梅西\n',
#  'finance\\t李大霄 ： 虽然 冲击 MSCI 失利 但 外资 进场 渠道 依然 通畅\n',
#  'sports\\t历数 中国 篮坛 高学历 人才 ： 邵婷 北师大 博士 曾令旭 清华 毕业\n',
#  'society\\t狮子 误触 陷阱 脖子 严重 溃烂 ， 等 死 的 它 竟 主动 到 动物园 求救 ！\n',
#  'car\\t丰田 6 月 在 华 销量 跌 11.3 % 卡罗 拉 滑坡 两位数 成 罪魁祸首\n',
#  'world\\t横霸 街头 ！ 超模 克鲁姆 真空 凸点 秀美 胸携四子 一字队 排开 气场 足\n',
#  'entertainment\\t小艺 范 《 如颖 随形 》 这才 是 真正 的 赵丽颖\n',
#  'tech\\t我用 微信 转发 文章 一天 赚 了 30000 元 背后 的 原因\n',
#  'travel\\t领略 丽江 最美 的 避暑胜地 ， 先睹为快 ！\n',
#  'car\\t1.4 T 全新 奥迪 A4L 曝光 马自达 新款 昂克 赛拉 泄露\n',
#  'tech\\t手机 12 强 咱 占 8 席 ! 联想 跌 最惨 !\n',
#  'society\\t广西 发布 防暑降温 通知 ： 40 ℃ 以上 应 停止 露天 作业\n',
#  'tech\\t银行 眼红 马云 支付宝 赚钱 ， 制裁 限额 支付宝 ， 支付宝 用户 怒 了\n',
#  'tech\\t滴滴 柳青 ： 中国 出行 市场 渗透率 仅为 1 % 发展 空间 巨大\n',
#  'entertainment\\t65 岁 大爷 遭遇 爱情 难题 ， 想 娶 80 后 小保姆 遭 儿子 反对 ， 你 怎么 看\n',
#  'world\\t旅美 商人 被误 当成 IS 成员 阿联酋 告诫 国民 出国 勿 穿 长袍\n',
#  'military\\t菲 志愿者 乘船 再 赴 仁爱 礁 ， 我 亲爱 的 祖国 还要 忍耐 到 几时\n',
#  'sports\\t伊布 加盟 曼联 要定 了 ！ 将 披 9 号 战袍 年薪 1000 万\n',
#  'society\\t监利 夫妇 借 高利贷 1 死 1 伤\n',
#  'sports\\t天津 媒体 狂赞 卡纳瓦罗 ： 现在 权健 的 传球 世界级\n',
#  'sports\\t有无 此人 差距 太 大 ， 易建联 时代 进 世界 前 8 已成 奢望\n',
#  'world\\t日 自民党 议员 出席 俄 执政党 大会 称 俄方 “ 重视 日本 ”\n',
#  'society\\t内蒙古 高校 毕业生 见习 补贴 怎么 补\n',
#  'entertainment\\t魏晨 被 网 红脸 女友 拴住 九年 ， 终于 要 修成 正果 了\n',
#  'travel\\t黑 龙滩 两天 一夜 化氏 饵料 钓 鳊鱼\n',
#  'travel\\t航海日志 ｜ 飘过 福冈 济州 , 太平洋 的 风 从 海面 吹过来\n',
#  'car\\t回首 皮卡 中国 行 2016 年 春季 巡展 之 路\n',
#  'entertainment\\t注意 韩红 的 表情\n',
#  'game\\t再 爆 更新 内容 皇室 战争 平衡 调整 可行性 分析\n',
#  'sports\\t斗转星移 ， 将士 情 ， 皇帝 泪\n',
#  'sports\\t他 身为 后卫 作风 勇猛 却 因 一次 犯规 被 球迷 称为 断腿 恶人\n',
#  'world\\t伊斯兰 经济 发展 快速 并 期待 强化 对华 合作\n',
#  'entertainment\\t有毒 ！ 有毒 ！ 易 烊 千玺 成 中老年 表情 包 绝对 主角\n',
#  'tech\\t年轻 就要 个性 ！ “ H5 开创者 ” 兔展 CEO 董少灵 ： 不 羡慕 腾讯 阿里\n',
#  'car\\t用心 感受 沃尔沃 V60\n',
#  'entertainment\\t新 《 木乃伊 》 曝 片场 照 刀锋 女 饰演 木乃伊 ( 图 )\n',
#  'finance\\tTCL 通讯 估值 被 港股 严重 低估 李东生 一 言 不吭 发起 私有化\n',
#  'entertainment\\t电视剧 也 有 暑期 档 ！ 最全 的 暑假 追剧 攻略 拿走 不谢\n',
#  'sports\\t德科 ： 小罗 的 天赋 远胜 梅罗\n',
#  'world\\t俄罗斯 再次 成为 内蒙古 第一 大 贸易 伙伴\n',
#  'society\\t维权 “ 关口 ” 前移 快 处理\n',
#  'society\\t媒体 揭 扶贫 黑手 为 群众 争取 一碗 肉 干部 要分 一口 汤\n',
#  'finance\\t持有 1000 亿美元 现金 的 微软 为何 举债 收购 LinkedIn ？\n',
#  'world\\t阿里 葬礼 被 家人 偷拍 要价 100 万美元 向 媒体 出售\n',
#  'world\\t舞娘 蒂塔万 提斯顶 毛绒 发卡 姿态 优雅 红唇 肤白 现身 机场 性感 依旧\n',
#  'entertainment\\t黄宗泽 ： 吻 戏太多 吓 到 徐子珊\n',
#  'entertainment\\t四五 月份 票房 暴跌 中国 电影 市场 碰到 天花板 ？\n',
#  'society\\t小伙 深夜 在 路边 捡了个 姑娘 _ 还 带回家 住 了 3 天\n',
#  'finance\\t[ 独家 专利 报告 ] 锂电池 ： 我 不能 再 低调 了 ！\n',
#  'baby\\t爸爸 带 孩子 ， 好处多多\n',
#  'military\\t歼 20 的 鸭翼 影响 隐身 ？ 谣言 传 了 一千遍 就 成 真相 了 .....\n',
#  'story\\t婶婶 虐待 我 ， 直到 我 发现 了 她 不敢 告人 的 秘密 2\n',
#  'story\\t邻家 姐姐 在 家里 看 那种 电影 ， 被 我 发现 了 （ 21 ）\n',
#  'society\\t击中 货车 窨井盖 突然 飞 起\n',
#  'entertainment\\t钟汉良 妻子 曝光 深 扒 钟汉良 女儿 妻子 资料 照片\n',
#  'world\\t上合 组织 媒体 代表团 访问 国际台\n',
#  'car\\t女司机 可以 省心 开车 了 ！ 福特 自动 驾驶 新感受\n',
#  'world\\t萨达姆 被 抓捕 后 ， 急切 想 把 他 处决 的 人 都 是 谁 ？\n',
#  'finance\\t阳光城 第二期 员工 持股 计划 6 月份 买入 2685 万股\n',
#  'tech\\t竞价 新手 成为 竞价 老鸟 的 自白 ？\n',
#  'world\\t吴 怀中 : “ 安倍 路线 ” 下 中日 磕碰 与 博弈 是 常态\n',
#  'history\\t开国 上将 之 苏振华 （ 难得一见 的 历史 照片 ）\n',
#  'entertainment\\t吴建豪 睽违 3 年 再 推 率真 情歌 全新 单曲 首 曝光\n',
#  'entertainment\\t大 潘献唱 《 麦兜 》 烹制 “ 反 鸡汤 之歌 ” 《 心灵 猪 汤 - 无敌 》\n',
#  'society\\t你们 不 分手 就别 回家 ！ 前男友 带 “ 兄弟 团 ” 棒打鸳鸯\n',
#  'society\\t3 岁 男孩 被 父亲 指挥 乞讨 嘴里 叼 着 烟\n',
#  'society\\t双性 婴儿 出生 15 天内 连续 三次 遭 亲人 谋杀\n',
#  'travel\\t2400 公里 自驾 呼伦贝尔 南北 全线\n',
#  'society\\t女子 赌气 回娘家 一年 后 回来 发现 丈夫 与 人生 子\n',
#  'sports\\t恒大 撕毁合同 开 了 坏头 ， 永昌 效仿 破坏 行业 秩序\n',
#  'car\\t为什么 叫 它 “ 撩姐 神车 ” “ 追爱座 驾 ”\n',
#  'car\\t这款 SUV 魅力 这么 大 ？ 80 后 小伙 的 抵日 情怀 竟 被 它 打败 了\n',
#  'sports\\t中国 · 凯里 四国 男篮 争霸赛 发布会 现场 活动 展现 浓郁 民俗风情\n',
#  'sports\\t西游记 后传 唐僧 和 无天 斗法 ， 被 打成 重伤\n',
#  'game\\t龙珠 GT 里 最强 的 BOSS 并 不是 一星龙 ， 连 破坏神 都 不是 他 的 对手\n',
#  'world\\t难民 危机 继续 恶化 百余人 经 希腊 小岛 进入 欧洲\n',
#  'finance\\t下周 好股 ： OLED 稀土 永磁 强者 恒强 牛者 更 牛\n',
#  'travel\\t乘坐 澳大利亚 最长 火车 ‘ 甘 ’ 号 列车 ， 体验 前所未有 的 澳式 旅程\n',
#  'car\\t美炸 了 的 大众 CC 改装 ， 可惜 都 离不开 万恶 的 大众 脸\n',
#  'entertainment\\t暮光 女 黑白 写真 大片 烟熏 搭 红唇 恣意 慵懒\n',
#  'sports\\t武磊 足协杯 遭富力 球员 连 打 带 踹 ， 孔卡伤 退 ， 上港 出局\n',
#  'society\\t在 新疆 ， 大串 烤肉 + 美女 更让人 流口水 哦 ！\n',
#  'finance\\t各路 资本 加速 涌入 体育产业 获 " 热 捧 " 五股 炙热\n',
#  'game\\t球球 大 作战 如何 寻找 角色 互换 的 时机 时机 把握\n',
#  'car\\t这货真 不 “ 运动 ” ， 深度 试驾 日产 西玛\n',
#  'regimen\\t家有 三年 艾 ， 郎中 不 用来 ！ 原来 艾叶 能治 这么 多病 ， 不看 亏大 了 ！\n',
#  'history\\t晚清 中兴 名臣 ， 差点 载 在 “ 朝阳 群众 ” 手里\n',
#  'game\\t死神 不是 这么 玩 的 ！ 守望 里 最 需要 思路 的 英雄 非他莫属\n',
#  'baby\\t妈妈 请 注意 ， 这 几种 食物 伤 孩子 大脑 ！ 扔掉 它 ！\n',
#  'history\\t这个 父亲节 ， 让 嘉靖 咋 过 ？ 他 一直 不 知道 他 的 爹 是 谁 ！\n',
#  'sports\\t麦迪 让 人 心碎 的 20 个 镜头 ， 不是 他 不 努力 ， 是 真的 没 办法\n',
#  'regimen\\t芝麻 最大 功效 竟 不是 乌发 ， 每天 一把 效果 惊人 ！ 妙方\n',
#  'regimen\\t多数 胃病 都 有 同一 病根儿 ！ 小小 蒲公英 终于 成为 济世 良药\n',
#  'history\\t他 非权 二代 却 22 岁 就 做 中将 毛主席 说 : 他 在 , 海军 司令 就 不 换人\n',
#  'discovery\\t银河系 中惊现 地外 生命 还 存在 另 一个 地球\n',
#  'discovery\\t阴谋 论者 声称 NASA 照片 显示 北极 上空 有 神秘 巨洞\n',
#  'society\\t电子眼 那么 智能 ， 真 就 拍 不到 渣土 车 ？\n',
#  'car\\t碉堡 了 ！ 德国 ETF 全轮 转向 卡车 原地 掉头\n',
#  'tech\\t老鹰 归来 焉知 非祸\n',
#  'game\\t刀塔 传奇 什么 阵容 三星 过 天空 神殿 ? 天空 神殿 怎么 三星 通关 ?\n',
#  'sports\\t郭 艾伦 ： 从未 承认 自己 是 第一 后卫\n',
#  'tech\\t吸引 人流 ： 打造 百万 粉丝\n',
#  'sports\\t05 年 榜眼 决定 留守 黄蜂 他 不愿 与 书豪 再 做 队友\n',
#  'sports\\t科比 走后 ， 湖人队 内讧 四起 ， 新秀 竟 再度 揭 队友 疮疤 ！\n',
#  'tech\\t中星微 发布 中国 首颗 28 纳米 量产 AI 芯片\n',
#  'finance\\t滨州 工商 公布 13 款 缺陷 童装 限 15 日 之内 整改 完毕\n',
#  'society\\t情侣 租 别墅 制毒 女 毒犯 求 与 男友 同判 死\n',
#  'tech\\t专访 WeX5 开发工具 CEO 马科 ： HTML5 就是 当前 App 开发 中 最 闪亮 的 网红\n',
#  'entertainment\\t跑 男脑 洞大开 上演 “ 十二生肖 悬案 ”\n',
#  'entertainment\\tTwins 合体 美颜 依旧 ！ 阿 sa 透视 裙 活力 、 阿娇 风情\n',
#  'military\\t中国 为何 不 清剿 越南 在 南沙 的 驻军 ?\n',
#  'tech\\t读懂 中国 母婴 行业 的 前世 今生 以及 母婴 新 商业 ？ 抓紧 看 这篇\n',
#  'entertainment\\t闺蜜 爱 上 前任 ， 友谊 变 心结\n',
#  'sports\\t划 龙舟 + 盛世 美颜 ， 恒大 外援 放假 都 在 干嘛 呢\n',
#  'entertainment\\t好 基友 一辈子 ！ 李光洙 将 捧场 宋仲基 香港 见面会\n',
#  'sports\\t冰岛 2 比 1 逆转 英格兰 挺进 8 强 ， 业余 门将 封杀 “ 三狮 军团 ”\n',
#  'game\\t亿万 粉丝 八年 期待 DNFIP 发布会 锁定 6 月 14 日\n',
#  'car\\tams 各国 主编 组团 测试 7 款 紧凑 级 SUV ， 猜 谁 是 赢家 ？\n',
#  'entertainment\\t《 星际 迷航 3 ： 超越 星辰 》 发布 七 主演 全新 海报\n',
#  'car\\t路虎神 行者 ： 威力 十足\n',
#  'society\\t四川 ： 德阳 两 毒贩 持枪 劫持 五名 人质\n',
#  'world\\t退欧 阵营 提示 选民 用 签字笔 以防 被 军情 五处 擦掉\n',
#  'sports\\t美国 vs 阿根廷 全 看点 潘帕斯 雄鹰 4 战 14 球誓 冲冠\n',
#  'baby\\t别用 无知 的 爱 去 破坏 孩子 的 专注 力 ！\n',
#  'car\\t防不胜防 ， 开车 最怕 的 8 个 盲区\n',
#  'sports\\t德国队 球员 化身 车间 工人 足球 球衣 签名 规模化\n',
#  'society\\t岳阳 、 郴州 2 名 处级 干部 涉嫌 严重 违纪 被 调查\n',
#  'game\\t卡牌 游戏 也 要 浸入 感 ， VR 炉石 怎么 玩 ？\n',
#  'car\\t5.4 L / 100km ！ 没想到 这台 豪华 SUV 的 油耗 可以 这么 低\n',
#  'finance\\t一则 阅读 量 高达 70 万 的 励志 创业 故事 ......\n',
#  'entertainment\\t明星 晒照 被 网友 炮轰 不 爱国 ， 你 觉得 有 道理 吗 ？\n',
#  'finance\\t282 股获 买入 评级 29 只股 或 涨超 50 %\n',
#  'finance\\t缠论 入门 学习 9 - - - - 表里 关系 ， 立体 的 完全 分类\n',
#  'entertainment\\t《 我 是 演说家 》 第三季 鲁豫乐嘉齐 开火 王刚 坐镇 强势 加盟\n',
#  'world\\t泰国 北部 已 进入 雨季 游客 赴 泰请 注意安全\n',
#  'sports\\t中超 - 高 拉特 阿兰 建功 恒大 2 - 0 夺 半程 冠军\n',
#  'tech\\t2016 全球 十大 品牌 出炉 谷歌 夺回 排行榜 首\n',
#  'car\\t女人 愿意 为 这 5 款 超级 豪车 终身 不嫁 ！\n',
#  'tech\\t升级 iOS10 之后 ： 这 23 款 iPhone 内置 应用 都 能 删除 了\n',
#  'finance\\t美国 公布 6 月 非农 就业人口 大增 好于 预期\n',
#  'world\\t她们 从小 就 “ 卖身 ” 在 寺庙 ， 成为 僧侣 的 玩物\n',
#  'military\\t网传 沈飞 正在 研制 垂直 起降 战机 ！ 军事 专家 这次 也 出来 表态 了\n',
#  'society\\t他 是 汶川 地震 最小 英雄 ， 曾立志 考 清华 结果 却 拍戏 ， 如今 长成 这样 了\n',
#  'sports\\t范加尔 和 穆帅 决裂 长达 19 年 师徒 情分 走 到 尽头\n',
#  'tech\\tSiri 蜕变 精明 管家 ： 苹果 iOS10 全新 Home 应用 详解\n',
#  'tech\\t微信 正在 慢慢 死去\n',
#  'entertainment\\t黎明 为何 一直 不愿 结婚 生子 ？\n',
#  'car\\t眼神 犀利 、 内外 升级 ！ 卡罗 拉 将 中期 改款\n',
#  'discovery\\t人类 探索 太空 的 历程 ： 非 光学 望远镜\n',
#  'sports\\t德国 球员 欧洲杯 表现 总评 ： 博阿滕 全队 最佳\n',
#  'sports\\t武汉 卓尔 宣布 前 尤文 主帅 正式 上任 将 与 卡纳瓦罗 斗智斗勇\n',
#  'world\\t晚报 ： 男女 塔顶 OOXX 被 拍 | 男子 将 2800 瓶 可乐 倒入 水池 游泳\n',
#  'entertainment\\t精忠 岳飞 岳家军 大破铁 浮屠\n',
#  'entertainment\\t《 跑 男 》 收官 ： 胖乔衫 亮点 多 ， 华晨 宇 却 让 郑恺 尴尬 ？\n',
#  'game\\t英雄 联盟 骚 词汇 和 段子 梗 ， 帮 你 更好 融入 电竞 家庭\n',
#  'sports\\t[ 独家 ] 欧洲杯 小组赛 揭秘 ： 谁 是 最大 赢家 ？\n',
#  'travel\\t我想 找个 女伴 一起 旅游\n',
#  'tech\\t延寿县 农村 电商 发展 迅速\n',
#  'car\\t宝马 X3 升级 NBT 大屏 ， 终于 有 导航 了 ！\n',
#  'finance\\t脱欧 公投 下午 开启 A股 “ 买 OR 卖 ” ？\n',
#  'sports\\t陆地 最强 中锋 没有 之一 最全 的 gif 合集\n',
#  'finance\\t四大行 “ 两 高一 剩 ” 贷款 余额 约 1.3 万亿元\n',
#  'baby\\t崔玉涛 谈 护理 科学合理 使用 空调 、 风扇 ， 宝宝 舒服 不 生病\n',
#  'world\\t55 岁 奶奶 减重 成 比基尼 模特 一周 吃 80 个 鸡蛋\n',
#  'finance\\t末日 博士 ： 英国 脱欧 或促 美联储 启动 QE4 ， 赶紧 买 黄金 ！\n',
#  'car\\t外带 五个 摄像头 ！ 13 升机 沃尔沃 FM 清道夫\n',
#  'game\\t《 无敌 9 号 》 的 通关 滚动 画面 有 四个 小时\n',
#  'world\\t特朗普 无 悬念 拿下 华盛顿 特区 ！ 离 确保 提名 更近 一步\n',
#  'game\\tLOL2015 泳池 派对 礼包 限时 上架 礼包 价格 公布\n',
#  'finance\\t货币基金 收益 大 滑坡 余额 宝 收益率 大跌 10 %\n',
#  'finance\\t场外 资金 何时 才 敢 大举 进场 ？\n',
#  'baby\\t想 快点 怀孕 ， 同房 次数 越多越好 吗\n',
#  'travel\\t夕阳 无限 好 ， 三 战 黄壁庄\n',
#  'world\\t香港 激进 反对派 游行 后 爆发 内讧 内部 成员 挑衅 互殴\n',
#  'world\\t菲律宾 国会 宣布 杜特 尔特 当选 下届 总统\n',
#  'society\\t小伙 将车 停放 在 别人 的 车位 上 ， 回来 看到 车时 ， 他 决定 要 走路 回家 了\n',
#  'world\\t伊拉克 政府军 再次 进逼 费卢杰 或 意在 为 政治危机 解围\n',
#  'history\\t他 是 国民党 猛将 ， 毛主席 更称 他 ： “ 狡如狐 ， 勇如虎 ”\n',
#  'tech\\t专访 KK 智能 云 音箱 创始人 杨得城 ： 两年 磨一剑 ， 只 为 音质 而生\n',
#  'world\\t华春莹 就 我 驻 马里 维和 人员 遇袭 发表谈话\n',
#  'society\\t夏天 摆地摊 卖 什么 最 赚钱 ， 他 居然 这样 就 轻松 月 赚 1 万元 ！\n',
#  'baby\\t2 岁 孩子 还 不会 说 整句话 ， 正常 吗 ？ 怎么 训练 ？\n',
#  'game\\t详解 为什么 守望 先锋 没有 小 地图\n',
#  'world\\t墨西哥 同意 向 美 引渡 头号 毒枭\n',
#  'tech\\t“ 父亲节 ” 最 走心 的 文案\n',
#  'sports\\t库里 ： 我 罚球 特准 纳什 ： 信不信 我 可以 教 所有人 做人 ？\n',
#  'finance\\t疯狂 的 “ 次新股 ” ， 涨幅 “ 较 小 ” 的 个股 仅剩 18 股 （ 名单 ）\n',
#  'tech\\t如果 你 做 的 PPT 不 想像 「 百度 UE 总监 刘超 」 那样 差点 被 赶下台 的话 ， 那么 ...\n',
#  'society\\t宝贝 回家 “ 孩子 去 哪儿 了 ” 系列 Campaign 正式 上线\n',
#  'world\\t亚洲 最 富裕 国家 ， 主动 要求 并入 另 一个 亚洲 大国 ， 结果 被 直接 拒绝\n',
#  'car\\t创驰 蓝天 ： 独领风骚 还是 孤掌难鸣 ？\n',
#  'society\\t厦门 机场 安检 提醒 ： 准妈妈 们 坐飞机 要 注意 啦 ！\n',
#  'car\\t这么 好 的 合资 SUV 只要 10 万出头 ， 全景 天窗 胎压 监测 全有 ！\n',
#  'world\\t非洲 研究 ： 信仰 巫术 可能 危害 国家 经济\n',
#  'tech\\t轻快 高效 智能 好玩 又 好 用 的 WPS 邮箱 4.0\n',
#  'entertainment\\t女星 走红 毯 不 穿 内裤 摔倒 太 搞笑 ， 就 不能 穿个 打 底裤 吗 ？\n',
#  'tech\\t班丽婵 ： 中小企业 真的 不要 再 做 APP 了\n',
#  'society\\t女子 在 路边 院子 看到 这样 的 一幕 ， 发现 真相 后 果断 报 了 警\n',
#  'society\\t执行 风暴 ： 拒 不 腾房 七旬 老汉 被 拘留\n',
#  'entertainment\\t《 小 丈夫 》 俞飞鸿 用 演技 为 姐弟恋 代言\n',
#  'entertainment\\t陈赫 前妻 疑交 外籍 帅气 新欢 共游 埃及 亲密 合影\n',
#  'entertainment\\t让 你 先 跑 一会\n',
#  'finance\\tA股 最新消息 ！ “ A股 反弹 下周 即将 展开 ” ！\n',
#  'car\\t时速 160KM 爆胎 ， 死亡率 是 100 % ， 做 啥 都 没用 ？\n',
#  'travel\\t钓友 最 喜欢 的 地方 ， 而且 草鱼 大 ！\n',
#  'game\\tLOL 囧 图 ： Dandy 你好 的 不教 就 会 带坏 猴爷 打斗 地主 ?\n',
#  'entertainment\\t第 52 届 韩国 百想 艺术 大赏 完整 获奖 名单\n',
#  'world\\t大众 CC 更换 美国 KN 进气 套件 ， 升级 比利时 Heinz 电脑 程序\n',
#  'entertainment\\t孕妇 汤 唯 与 刘若英 素颜 合影 网友 调侃 : 还 不 ps !\n',
#  'game\\t专业 电 竞酷 炫 利器 ！ AOC32 吋 曲面 显示器 评测\n',
#  'sports\\t伊斯拉 ： 我 配不上 尤文 的 球衣\n',
#  'tech\\t推广 | 中兴通讯 董事长 赵先明 博士 ： IOT 将 彻底改变 人类 生产 生活 方式\n',
#  'tech\\t首家 ODM 模式 电商 网易 严选 上线\n',
#  'car\\t给 汽车 装 上 “ 中国 心 ”\n',
#  'car\\t东风 雪铁龙 新 C4L 实车 曝光 车身 大幅 加长\n',
#  'game\\tSS 经理 左雾 澄清 ： 关于 Uzi 被演 一事 别乱 带 节奏\n',
#  'society\\t暑运 服务 早 知道 | 北京铁路局 28 趟 旅游 专列 开启 “ 避暑 游 ”\n',
#  'sports\\t李章洙 现身 日本 为 亚泰 选援 进京 反戈 国安 盼 抢分\n',
#  'entertainment\\t老友 鬼鬼 18 年 ！ 欧阳震华 带挈 滕丽名 ， 坐 正 无线 福将 之位\n',
#  'entertainment\\t歌手 严爵 否认 劈 腿 ： 我 没 亏待 也 没 对不起 小 8\n',
#  'tech\\t颠覆 生活 的 下 一个 风口 ， “ 区块 链 ” 究竟 是 什么 ？\n',
#  'world\\t日本 电视节目 采访 外国人 ， 为何 专找 欧美 白人 ？\n',
#  'world\\t英国人 为啥 那么 想 脱欧 ？\n',
#  'entertainment\\t陈冰 ， 这 是 你 一个 女孩 该 做 的 事 吗 ？\n',
#  'food\\t好玩 不能 饿肚子 全球 迪士尼 到底 有 啥 好吃 的 ？\n',
#  'sports\\t格策 铁心 要 和 渣 叔 对着干 ！ 先 拒绝 加盟 如今 又 要 为 敌\n',
#  'finance\\t郑洛新 国家 自主 创新 示范区 建设 实施方案 印发\n',
#  'world\\t惹不起 ！ 温哥华 的 乌鸦 最近 疯 了 每天 袭击 200 人\n',
#  'tech\\t分享 二次 接线图 识别\n',
#  'entertainment\\t李敏 镐 现身 成都 苏州 两地 SNS 晒 与 导演 自拍照\n',
#  'car\\t快评 ： 6 月 本田 增长 31.8 % 讴歌 下降 54.6 %\n',
#  'society\\t肖锋 ： 《 欢乐颂 》 — — 为什么 你 嫁 不了 豪门 ， 娶 不了 女神\n',
#  'car\\t入坑 《 老 九门 》 ？ 你 知道 它 的 男主 都 爱车 嘛 ？ 带 你 盘点 明星 们 的 豪车\n',
#  'military\\t全球 十大 科幻 战舰 ， 中国 上榜 的 你 肯定 猜 不到\n',
#  'finance\\t陈 海峰 ： 黄金 受 哄抢 对 贵金属 企业 将 是 一个 新机遇\n',
#  'entertainment\\t撞 脸 Angelababy 的 女星 竟然 这么 多 ， 但 最后 一个 最像 ！\n',
#  'car\\t海选 逆袭 的 机会 来 了 ！ 这些 豪华 品牌 SUV 降幅 竟高达 10 万\n',
#  'game\\t雪峰 玉腿 精彩 演绎 DOTA 女英雄 ， 最后 两张 亮 瞎 了\n',
#  'car\\t2016 下半年 将 上市 重磅 SUV 前瞻\n',
#  'finance\\t2016 大底 进入 倒计时 ? 下周 A股 四大 看点\n',
#  'tech\\t2000 元 以上 智能 手表 可 接受度 最高\n',
#  'society\\t送 快递 不 只是 体力 活儿 ！ 机警 快递 小哥 协助 破案 获 重奖 30 万\n',
#  'sports\\t中国 商人 购入 NBA 及 WNB A股 份\n',
#  'car\\t汽车空调 开 的 越 大 油耗 就 越 高 ？\n',
#  'car\\t全新 奥迪 A6 最低 27 万 ！ 虽然 比 不过 奔驰 E ， 但 妥妥 赢 了 宝马 5 系\n',
#  'entertainment\\t有钱 就 得 这么 任性 吗 ？ 强势 富婆 非 要 老牛 吃 嫩草 ， 真相 凌乱 引 公愤\n',
#  'military\\t蔡正元 : 我 第一 时间 披露 了 台军 导弹 误射\n',
#  'society\\t震惊 ！ 锡 纸条 四秒 开锁 八成 防盗门 不 防盗 ！\n',
#  'society\\t朋友 新开 的 店 ， 说 随便 喝 ！ 原来 这么 坑 ！\n',
#  'world\\t韩国 将 帮助 越南 清除 越战 遗留下来 的 炸弹 和 地雷\n',
#  'sports\\tFIFA16 欧洲杯 最佳阵容 ： C 罗贝尔 领衔\n',
#  'society\\t酒店 消费 起纠纷 民警 帮忙 来 协调\n',
#  'entertainment\\t《 余罪 》 的 败笔 大 胸姐 ， 还有 余罪 的 太 随意\n',
#  'sports\\t科比 + 周杰伦 + 刘烨 + 金钟国 ， 这个 画风 一看 就 很 贵 ！\n',
#  'car\\t买 宝马 必须 加价 三千块 ？ — — M54 发动机 vanos 维修 实录\n',
#  'history\\t比 李云龙 还 牛 的 人物 ， 55 年 毛主席 破例 批示 由 少将 晋升为 中将\n',
#  'finance\\t玉米 种植 ： 5000 万亩 和 5 亿亩 的 平衡\n',
#  'tech\\t轻松 两步 移动 手机 流量 免费 用 （ 移动 正规 活动 非 漏洞 ）\n',
#  'entertainment\\t《 盗墓 笔记 》 曝 预告 8 月 5 日南派 开启 寻秘 征程\n',
#  'tech\\t约车 新政 将 出台 ， 滴滴 优步 哭 晕 了 ， 这家 公司 却 爽歪歪 ！\n',
#  'entertainment\\t图虫 毕业 摄影 ： 毕业 季 mv － 你 曾 是 少年 ｜ 剧照\n',
#  'society\\t奇葩 悉尼 富人 区 一户 人家 爱好 竟然 是 收 垃圾\n',
#  'car\\t它 同样 源自 德国 血统 比 高尔夫 大 一圈 关键 是 回头率 更高\n',
#  'essay\\t其实 ， 谁 都 过 得 不 容易\n',
#  'finance\\t股民 最 关心 的 五穷六绝 七 翻身 原来 是 这 意思\n',
#  'sports\\t他 抱 着 女友 当网 红 ， 男友 力 MAX 爆棚\n',
#  'entertainment\\t继 《 伪装者 》 和 《 琅 琊 榜 》 后 ， 她 又 一次 惊艳 了 岁月\n',
#  'world\\t阎学通 三年 前 对 英国 脱欧 “ 神 预测 ”\n',
#  'car\\t比亚迪 K6 纯 电动 客车 产品 亮点 解析\n',
#  'sports\\t垂钓 鲤鱼 时 搭配 子线 的 技巧 和 经验\n',
#  'car\\t别老 嫌车 内 降温 太慢 你 根本 没用 对 出风口\n',
#  'finance\\t周小川 ： 人民币 汇改会 更 灵活\n',
#  'story\\t数十 股东 在 会议 上 大吵 ， 保安 看不下去 用 武力 解决\n',
#  'entertainment\\t《 我 去 上学 啦 》 独家 剧透 ， 绝无仅有\n',
#  'finance\\t84 股 机构 首次 关注 格林 美 涨幅 空间 最大\n',
#  'society\\t市人 社局 严 把 内控 管理 确保 社保 基金 安全\n',
#  'entertainment\\t想不到 他 不仅 情商 低 ， 而且 整容 撞 脸 了 整个 娱乐圈 男明星 ！\n',
#  'car\\t东风 风神 SUV 将 增至 8 款 推 跨界 / 混动 车型\n',
#  "fashion\\t赶超 Gigi | 高冷 扑克 脸 ， 敢 露会 穿 的 她 可 不止 ' ' 妹 二代 ' ' 这么 简单 ！\n",
#  'car\\t2016 款 福特 野马 美规 - 加版 型号 区分 方法 及 配置 差异\n',
#  'world\\t美国 与 《 联合国 海洋法 公约 》 竟然 是 这种 关系\n',
#  'finance\\t中国 与 俄罗斯 考虑 建立 联合 黄金 矿业 基金\n',
#  'society\\t打车 易 维权 难 ， 网络 约车 让 人 又 爱 又 恨 何去何从 ？ ！\n',
#  'sports\\t恒大 欧洲 选帅 ， 斯科拉里 “ 输 ” 宁 就 下课 ？\n',
#  'baby\\t一声 炮响 ， 宝宝 抓 着 耳朵 哭 ， 说 聋 了 ， 我 两腿 发软\n',
#  'society\\t网友 爆料 ， 姜堰 俩 男子 大马路 上互 捅 ， 满地 都 是 血 ! ！\n',
#  'finance\\t新疆 15 日 发行 47 亿 地方 债\n',
#  'entertainment\\t自信 女 表白 上司 ， 剧情 反转 事实真相 让 全场 惊呆 ！ 亲友团 竟是 情敌 ！\n',
#  'entertainment\\t王 铮亮 升级 当奶 爸 网友 ： 张杰 、 魏晨 ， 你们 也 要 抓紧 了 ！\n',
#  'tech\\t乐视 影视 会员 跨界 权益 创造 生态 营销 新 概念\n',
#  'game\\t问道 手游 结婚 系统 前瞻 万众瞩目 结婚 开放\n',
#  'car\\t男子 酒驾 被 查 怀孕 妻子 躺 交警 车头 “ 晒 ” 大长 腿\n',
#  'car\\t为什么 说 改装 电子 油门 加速器 后 ， 1.6 的 车子 开 起来 像 2.0 的 ？\n',
#  'entertainment\\t怀念 家驹 | 原谅 我 这 一生 不羁 放纵 爱 自由\n',
#  'essay\\t心存 美好 ， 人生 四季 皆 是 春\n',
#  'car\\t大众 地位 无法 撼动 一大 波 SUV 将 接踵而来\n',
#  'story\\t民间故事 ： 肇事 司机\n',
#  'entertainment\\t韩红首认 初恋情人 居然 是 他 ！ 曾 被疑 出柜恋 上 管彤 为何 至今 不 结婚\n',
#  'car\\t夏天 车辆 被 暴晒 ， 车内 太热 ， 这个 技巧 几秒 就 能 降温\n',
#  'entertainment\\t明星 出 道 十年 对比 剧照 ， 一直 不变 的 原来 是 他 ！\n',
#  'car\\t差价 100 倍 又 怎样 ， 你 以为 法拉利 就 能 斗得 过 我 的 五 菱之光 了 ？\n',
#  'society\\t详解 四川 巴中 16 岁 少年 如何 偷渡 到 迪拜\n',
#  'travel\\t与 藕花 相伴 ， 做 一个 幸福 的 济南人\n',
#  'sports\\t诺 伊尔 ： 不想 让 博努奇 进 我 两个 点球\n',
#  'history\\t民国 四大 公子 的 他 竟然 是 民国 首富 ， 日本 人 抄 他 的 家 竟然 被 钱 吓 到 了\n',
#  'sports\\t中国 体操队 确认 出征 里 约 奥运会 队员 名单\n',
#  'military\\t考上 清华 ， 我 仍 是 一名 预备役 战士\n',
#  'entertainment\\t这样 的 刘诗 诗 真是 美 得 惊为天人 ， 这 身材 真是 让 吴奇隆 赚 到 了 ！\n',
#  'travel\\t瓦伦西亚 ， 偶遇 一场 宗教 盛会\n',
#  'finance\\t长江 农业 推荐 生猪 养殖 股 ： 挑战 生猪 养殖 股 一致 预期 的 时候 到 了\n',
#  'finance\\t新规亮 剑 壳 炒作 釜底抽薪\n',
#  'finance\\t韩媒 看 中国 晋江 : 从 " 品牌 之 都 " 迈向 " 文创 之城 "\n',
#  'entertainment\\t郭德纲 获 保镖 护驾 似 老大 遭 美女 搭讪 侧目 偷 瞄\n',
#  'game\\t刀剑 神域 黑衣 剑士 诗 乃 阵容 推荐 ALO 诗 乃 阵容\n',
#  'entertainment\\t李易峰 车祸 后续 | “ 兰博基尼 半年 没 开 ” 的 说法 是否 撒谎 ？\n',
#  'entertainment\\t他 为 娱乐圈 真是 操 碎了心 盘点 被 王思聪 炮轰 过 的 明星\n',
#  'world\\t《 福布斯 》 最具 影响力 女性 排行 默克尔 居首\n',
#  'tech\\t反向 看 富士康 收购 诺基亚 ， 这 或许 才 是 交易 的 真实 结局\n',
#  'sports\\t不吐 不快 | 大部分 中国 影视剧 里 的 围棋 都 有 槽 点 ...\n',
#  'travel\\t鹏城 俯瞰 ， 大美 深圳 ， 山海 相连 ， 高楼 林立\n',
#  'story\\t火车 卧铺 ， 藏 在 窝里 等 流氓 的 女鬼 ！\n',
#  'entertainment\\t林志颖 和 张卫健 年轻 时长 的 真 像 ！ 陈冠希 有种 病态 美\n',
#  'society\\t“ 尼伯特 ” 致 福建 多处 内涝 逾 20 万 人大 转移\n',
#  'sports\\t缘分 ！ 瓜 迪奥拉 ： 当年 曼城 差点 签下 我\n',
#  'regimen\\t1 味 中药 有大毒 ， 人称 “ 山 砒霜 ” ， 却 能治 风湿 关节炎 ， 还 能 抗癌\n',
#  'entertainment\\t刘烨 狂 吃 榴莲 停不下来 诺一 霓娜 却 捂 嘴 一脸 惊恐\n',
#  'society\\t你 家门 上 如果 有 这个 ， 赶紧 处理 掉 ！ 小心 被 盯上 ！\n',
#  'sports\\t新闻 ： UFC 和 Glory 顶级 选手 6 月 组队 来京 开设 训练营\n',
#  'tech\\t独身 者 的 理想 乡 ： 有关 VR 观影 的 一点 创想\n',
#  'tech\\t拥有 市值 6000 亿 的 公司 , 却 在 食堂 跟 员工 用餐 在 路边 排队 等车\n',
#  'entertainment\\t玉置浩二 病愈 发誓 戒酒 前 晚 复工 补办 个 唱\n',
#  'world\\t南海 仲裁 六大 看点 解析 ： 人工岛 享有 200 海里 经济区 吗 ？\n',
#  'game\\t疯狂 降价 ！ 微软 XBOXONES 国行 年底 上市\n',
#  'game\\t攻防兼备 ！ 《 王者 荣耀 》 老夫子 攻略\n',
#  'car\\t6 月 “ 星 ” 车 推荐 ： 最 适合 年轻人 的 SUV — — 海马 S5\n',
#  'tech\\t宝鸡 首家 微信 申贷 平台 在 岐山 正式 运行\n',
#  'car\\t新手 买 二手车 ， 几点 须知 ！\n',
#  'tech\\t华为 PK 小米 ， 谁 才 是 国产手机 的 老大 ？\n',
#  'car\\t够 “ 黑 ” ！ 走进 亚洲 最大 “ 汽车 炼狱 ” 解密 别克 安全 “ 源代码 ”\n',
#  'finance\\t今日 市场 血流成河 ！ 股民 提前 预言 主力 出货 ， 节前 清仓\n',
#  'sports\\t欧洲杯 城市 巡礼 | 圣埃蒂安\n',
#  'world\\t泰国 诗琳通 公主 摄影展 在 成都 开幕\n',
#  'finance\\t长江三角洲 城市群 发展 规划 ， 江苏 九市 将 扮演 什么 角色 ?\n',
#  'entertainment\\t稀有 资源 : 迪士尼 电影 独家 幕后 照片\n',
#  'entertainment\\t2016 香港 小姐 第二轮 面试 了 网友 ： 我要 洗洗 头出 道 了 ！\n',
#  'car\\t奇瑞 瑞虎 51.5 TCVT 版 将 于 7 月 内 上市\n',
#  'world\\t习近平 将 主持 G20 杭州 峰会\n',
#  'tech\\t这家 公司 仅用 6 年 时间 ， 就 赶超 亚马逊 成为 韩国 “ 电商 之王 ”\n',
#  'tech\\t2016 年 改变 制造业 的 6 大 革命性 技术\n',
#  'tech\\t学会 这个 ， 不管 做 什么 行业 都 不缺 客户\n',
#  'finance\\t如何 判断 熊市 底部 ？\n',
#  'world\\t日本 对 中国 用情 不 专 ， 东南亚 游客 成 “ 备胎 ”\n',
#  'entertainment\\t网 曝 杨 幂 因不雅 视频 早已 离婚 刘恺威 未 表态 默认 ？\n',
#  'entertainment\\t没 人 喜欢 李英爱 家 的 龙凤胎 吗 ？ 他们 现在 长 这样 ！\n',
#  'car\\t大众 和 丰田 ， 谁 的 未来 更 靠 谱 ？\n',
#  'food\\t炎热 的 夏天 吃 凉拌 肉 美美 达\n',
#  'entertainment\\t传 SMAP 分裂 骚动 继续 香取 慎吾对 木村拓哉 不满\n',
#  'car\\t喜 提白狮 1.6 T 睿 驰\n',
#  'tech\\t麻省理工 科技 评论 ： 中国 互联网 正在 蓬勃发展\n',
#  'story\\t小 草根 去 美国 种 荸荠 ， 因有 一 神秘 动物 帮忙 ， 荸荠 丰收 ， 他发 了 大财\n',
#  'baby\\t胎儿 发育 迟缓 的 症状 都 有 哪些 呢 ？\n',
#  'world\\t考 眼力 时间 到 ! 松鸡 天然 伪装 石块 中\n',
#  'military\\t官兵 抗洪救灾 ： 重温 堤坝 上 那些 难忘 瞬间\n',
#  'car\\t“ 跑 男 ” 同款 ， 23 万 入手 宝马 首款 家庭 实用性 MPV ， 车主 这样 说\n',
#  'sports\\t今夏 蓄力 反弹 6 球星 : 浓眉 领衔 哈登 湖人 榜眼 上榜\n',
#  'society\\t发放 司法 救助金 温暖 刑事 受害人\n',
#  'entertainment\\t《 孤芳 不 自赏 》 baby 造型 超仙 超美 眼神 满满 都 是 戏\n',
#  'society\\t不买 保险 就 不能 提车 ？\n',
#  'sports\\t捷克 地区 联赛 点球 大战 52 球分 胜负 创纪录\n',
#  'sports\\t鲁能 五轮 不胜 将 战国 安 难兄难弟 为 三分 而战\n',
#  'society\\t同居 后 又 分开 的 需要 返还 彩礼 吗 ？\n',
#  'sports\\t世界杯 夺冠 她 被 指郎妈 照顾 打 德国 险 输球 她 去 里 约 悬 了 ？\n',
#  'tech\\t苹果 申请 了 新 专利 用户 能 更 方便 地 单手 使用 iPhone\n',
#  'entertainment\\t网红界 的 一股 清流 ： papi 酱 的 毕业 照 ， 萌萌 哒 ！\n',
#  'tech\\t李彦宏 称 小米 吧 已 卖 给 小米 ， 小米 高管 回应 又 躺 枪\n',
#  'finance\\t银行 理财 收益 又 闻 涨声\n',
#  'story\\t到 员外 家 干活 太 抠门 一盘 咸鱼 摆 了 一年 ， 师傅 的 举动 让 他 失去 传家宝\n',
#  'car\\t全新 一代 smartfortwo 敞篷版 7 月 上市\n',
#  'car\\t6 月 国内 热销 SUV 排行榜 新鲜出炉 ！ 哈弗再 夺冠\n',
#  'baby\\t明明 是 你 惹 毛 了 孩子 ， 还 不准 他们 哭\n',
#  'sports\\t今天下午 15 : 30 辽足 火力 全开 能否 终结 9 轮 不胜 ？\n',
#  'military\\t每七架 摔 一架 的 寡妇 机 ： 越南 搜寻 失踪 苏 30 战机 的 神眼 巡逻机 坠毁\n',
#  'car\\t大嘴 车头 是 靓点 MaseratiLevante 首度 現身 亞州\n',
#  'car\\t绚烂 无比 奥迪 A4 珠光 白 车身 改色 贴膜\n',
#  'tech\\t醉 了 ， 99 % 的 人 手机 浏览器 都 有 这种 大 问题 ！\n',
#  'finance\\t下调 缴费 上限 ， 或 为 企业 减负 “ 灵活 版 ” 企业 年 金 倒计时\n',
#  'entertainment\\t台湾歌手 黄安 ： 毛宁 的 巡演 得到 水泥厂 支持 ， 赞助 水泥 20 吨 ！\n',
#  'finance\\t深交所 要求 万科 核实 变 身 国企 传闻\n',
#  'sports\\t德国 终于 第一次 赢 意大利 ， 你们 竟然 偷偷 跑 去 干 这种 事 ！\n',
#  'game\\tLOL 各大 国家 女神 玩家 ， 韩国 整容 脸 ， 中国 妹子 萌\n',
#  'society\\t农村 少女 的 城市 梦 什么 时候 可以 醒 三\n',
#  'finance\\t坚持 这 七个 铁律 ， 钱 对 你 来说 只是 数字 而已 ！\n',
#  'entertainment\\t这 一次 ， 皮克斯 只是 太 温情 了\n',
#  'tech\\t出海 ， 移动 电商 的 下 一个 风口 ？\n',
#  'travel\\t忆 故乡 （ 友情 推荐 ）\n',
#  'tech\\t融资 3 千万 ， 他造 了 一台 名为 小忆 的 机器人 ， 要 向 世人 传递 AI 的 温度\n',
#  'car\\t国产 众泰 T600 问题 不断 ， 真的 是 菜鸟 组装车 吗 ？\n',
#  'finance\\t全国 最大 小龙虾 出口 基地 去年 网络 销售 超过 １ 亿元\n',
#  'game\\t一股 神秘 力量 席卷 了 全国 各大 影院\n',
#  'finance\\t脱 欧后 全球 局势 复杂 军工 板块 或 将 爆发\n',
#  'sports\\t奥运 跳水 名单 公布 ： 30 岁 秦凯 再战 奥运 司雅杰 迎首秀\n',
#  'society\\t辽宁 小伙 遇 现实 版 “ 白蛇传 ” 小蛇 救 了 小伙 一家人\n',
#  'world\\t侧面 无限 好 风光 ！ 蕾 哈娜 似 真空 上阵 未见 bra 摆 “ 扑克 脸 ” 懒理 镜头\n',
#  'entertainment\\t中国 科幻 大片 《 三体 》 到底 在 拍 什么 ？ 幕后 工作 照曝光\n',
#  'car\\t第四批 动力电池 企业目录 ， 政策 开始 打 起 “ 保卫战 ”\n',
#  'military\\t令美 头疼 的 " 搅局 者 " ： 歼 31 发动机 改良 后 将 打破 F35 出口 垄断\n',
#  'society\\t上海 自己 报警 的 作案人 ： 作案 过程 被 记录 得手 后 举止 异常\n',
#  'sports\\tWWE 极限 时刻 ！ 那些 让 你 忘不掉 的 恐怖 瞬间 ！\n',
#  'tech\\t（ 重磅 ） 百分之九十九 的 化工 人 都 不会 错过 的 工业原料 知识 汇总 ！\n',
#  'world\\t女孩 18 岁 当选 美 皇后 曾 因 额头 太大 被 嘲讽 长得 丑\n',
#  'history\\t蒋介石 的 御林军 到底 是 哪个 部队 ？\n',
#  'game\\t《 300 英雄 》 绝版 皮肤 和 英雄 限时 上架 ！\n',
#  'tech\\t捷成 股份 牵手 AURO 与 世优 科技 发力 3D 音频 及 AR / VR 技术\n',
#  'travel\\t徐州 某 水库 ， 三 小时 ， 爆护 27 斤 ！\n',
#  'baby\\t44 岁 孕妈 怀孕 31 周 体重 高达 600 斤 ， 目前 仍 在 积极 增肥\n',
#  'entertainment\\t《 法则 》 李亚鹏 黄子 韬 蓬头垢面 笑靥 如花\n',
#  'game\\tMOBA 手游 《 自由 之战 》 新 版本 全 平台 更新\n',
#  'sports\\t一百年 前 的 北京 紫禁城\n',
#  'society\\t99 % 以上 的 客诉 与 奶粉 质量 无关 ， 多些 理解 ， 少 些 误解\n',
#  'car\\t看到 全新 驭 胜 S350 实车 了 ， 挺不错 的\n',
#  'entertainment\\t贾静雯 因 偏爱 小女儿 ， 遭 网友 质疑\n',
#  'car\\t20 万元 是 买 斯柯达 速派 还是 大众 帕萨特 ？\n',
#  'sports\\t葡媒 ： 狐狸 愿 2000 万欧 引进 葡萄牙 国脚\n',
#  'finance\\t把 绿色 金融 打 造成 绿色 发展 的 新 引擎\n',
#  'discovery\\t太阳系 发现 超级 星球 第九 颗 行星 或是 宜居 星球\n',
#  'sports\\t冯天薇 或成 奥运 二号 种子 频繁 参赛 拉高 全队 排名\n',
#  'entertainment\\t宋仲基上 亿 签约 金 跳槽 中国 公司 ？ 所属 经纪 公司 否认\n',
#  'world\\t第三届 中 英 司法 圆桌会议 举行 周强 廖柏嘉 致辞\n',
#  'finance\\t香港 ： 这座 城市 充斥 着 千亿 富豪 ， 却 没有 一家 十亿 估值 的 初创 企业\n',
#  'food\\t好 先生 （ 太太 ） 必备 ， 快手 煲汤 还 不 赶紧 学 ！\n',
#  'car\\t你 想 知道 网红 “ 顺丰 R1 快递 哥 ” 的 故事 吗 ？\n',
#  'tech\\t易绚 模型 ： 把握 CG 制作 产业 咽喉 命脉 ， 撬动 千亿 级 市场\n',
#  'game\\t炉石 传说 标准 模式 新版 变速 猎 平民 卡组 推荐\n',
#  'tech\\t面试 ： （ 下篇 ） \u200b 让 面试官 说 IWANTYOU ！\n',
#  'car\\t福特 野马 女司机 报复 前男友 ， 逆向 撞 翻 自行车\n',
#  'sports\\t过 亿 合同 频现 ！ NBA 正 上演 史上 最 壕 转会 季 ， 但 赢家 绝 不止 是 康利\n',
#  'society\\t为什么 法国 女人 不买 名牌 包 ？\n',
#  'society\\t巴林右旗 干部群众 全力 抗旱\n',
#  'finance\\t7 月 5 日 7 家 上市公司 现 利空\n',
#  'society\\t多省 平均工资 出炉 哪个 行业 富人 最 多 ？\n',
#  'military\\t国防部 回应 所谓 南海 仲裁 案 最终 裁决 将 公布\n',
#  'finance\\t“ 先知先觉 ” 资金 赚得 盆满 钵 满后 觉者 低吸 跟进\n',
#  'entertainment\\t孙俪 凭 《 芈 月 传 》 再 获 上海 电视节 视后 激动 落泪 哽咽\n',
#  'finance\\t中报 高送 转下个 花落谁家 10 股 或 有戏\n',
#  'tech\\tScience ： 细胞 利用 核 ATP 紧急 驱动 DNA 修复\n',
#  'society\\t女子 持刀 闹事 民警 临危不惧\n',
#  'regimen\\t身体 的 1 个 信号 不起眼 但 却 致命\n',
#  'car\\t扮猪 吃 老虎 的 说 的 就是 这辆 车 ， R36\n',
#  'tech\\t这 2 个 字 ！ 决定 了 微商 是否 赚大钱 ！\n',
#  'entertainment\\t爹 丑娘 再 好看 也 是 白搭 ， 娱乐圈 丑 的 不要 的 星 二代\n',
#  'tech\\t2016 年 Q2 网络安全 创新 500 强榜 : 360 奇虎 仅排 126 ？\n',
#  'car\\t悲 催 了 作死 驾驶员 倒车 不关 仓门 叉车 摔坏 这下 赔惨 了\n',
#  'car\\t虽然 有些 模仿 痕迹 ， 但 北汽 “ 揽胜 ” 气质 丝毫 不输路 虎 ！\n',
#  'history\\t开国 将领 中 最能 打 的 " 战将 " ， 他 刷新 了 八路军 击毙 日军 的 最高 将领\n',
#  'finance\\tP2P 理财 优势 明显 红岭 、 小牛 在线 、 三益 宝受 好评\n',
#  'society\\t论文 涉嫌 抄袭 被 撤销 学位 北邮 硕士 将 学校 告上 法庭\n',
#  'sports\\t建业 遭遇 两连败 ？ 重新 开始 保级 ？\n',
#  'travel\\t色香味 的 赋春\n',
#  'game\\t《 魔兽 》 电影 蓝光 版 10 月 海外 发售 ， 包含 删减 片段 ！\n',
#  'sports\\t无缘 大赛 之人 谁 最 倒霉 多特 双星 不及 他 一人 唏嘘\n',
#  'car\\t25 万 的 2.0 T 涡轮 车 ， 动力 居然 比 200 万 的 5.0 自吸 还 猛\n',
#  'finance\\t五年 内 510 万人 将 失业 包括 白领 ， 你 的 岗位 处于 边缘 还是 核心\n',
#  'tech\\t在 监控 布线 中 ， 对 RVV 电源线 的 规格 选择\n',
#  'sports\\t比利时 迷失 自我 威尔士 三 军用 命助 贝尔 战 C 罗\n',
#  'world\\t王毅 对 美国 国务卿 说 ： 南海 仲裁 闹剧 该 收场 了\n',
#  'fashion\\t夏季 时髦 套路 就是 这 5 件 ！ 买 再 多 也 都 是 浪费 钱\n',
#  'travel\\t盘点 32 个 省会 城市 的 奇葩 建筑 ， 看看 哪个 最亮 瞎 你 的 眼 ？ （ 图 ）\n',
#  'military\\t你 有 一份 来自 火箭 军 的 邀请 , 请 及时 查看\n',
#  'society\\t抢 了 29 元 钱 男子 被 抓获\n',
#  'history\\t“ 钟馗 ” 起源 四种 解释\n',
#  'history\\t唯一 没 被 改编 成 新四军 的 南方 红军 游击队 ： 23 年间 红旗 始终 不倒\n',
#  'game\\t盘点 炉石 传说 中 那些 你 不 知道 的 冷 知识\n',
#  'society\\t申城 ： 免费 乘车 取消 第一天 少数 老人 不 习惯\n',
#  'tech\\t想 买 宋仲基 的 同款 耳机 ？ 有 必要 「 安利 」 你 一款 更棒 的\n',
#  'society\\t“ 凿 ” 通 致富路 - - 当代 “ 女 愚公 ” 邓迎 香 的 故事\n',
#  'essay\\t婚后 ， 男人 最 愿意 爱着 哪种 女人\n',
#  'finance\\t紧靠 OLED 热点 发布 项目 投产 公告 凯盛 科技 遭 上证所 问询\n',
#  'sports\\t昔日 盖帽 三双 内线 接近 复出 ， 一队 有 他 夺冠 在 望\n',
#  'world\\t巴格达 一 菜场 遭 汽车 炸弹 袭击 致 40 多人 死伤\n',
#  'sports\\t骑士 将 与 克里斯 - 安德森 签约 ？\n',
#  'car\\t当下 最火 的 自主 SUV ， 在 东莞 大秀 实力\n',
#  'society\\t李大伟 ： 上海 腔调 （ 上 ）\n',
#  'tech\\t死鬼 ， 叫 你 不要 做 通信 ！\n',
#  'entertainment\\t普华永道 预计 2017 年 中国 电影票房 全球 第一\n',
#  'baby\\t为了 阻止 婆婆 给 宝宝 把 尿 ， 我 跟 她 吵 了 起来 ！\n',
#  'tech\\t工信部 或 叫停 非 运营商 免费 通话 ， 微信 、 钉 钉 、 易信 一大堆 都 中枪 了\n',
#  'world\\t伊朗 威胁 封锁 霍尔木兹海峡 ， 中国 会 效仿 封锁 南海 对抗 美国 吗 ？\n',
#  'travel\\t千湖 千岛 千佛千塔千堡 千丘 ， ， ， ， ， ， 之 国\n',
#  'car\\t老 司机 车技 好不好 ， 就 看过 弯 技巧 叼 不 叼\n',
#  'history\\t慈禧太后 的 私生活 之谜\n',
#  'tech\\t为什么 说 乔布斯 比马云 伟大 ？\n',
#  'sports\\t波尔 ： 五战 奥运 状态 良好 ， 张继科 上 单打 让 我 很 意外\n',
#  'sports\\t梅威瑟 炫富 新招 ！ 人民币 2.4 亿买 飞机 ！ 内部 装饰 奢华 令人咋舌\n',
#  'history\\t最后 一颗 子弹 ， 打中 了 女 战友 ， 当场 倒地 ？\n',
#  'sports\\t男篮 备战 ： 周琦冰 敷 膝盖 场边 拉伸 再献 一神图\n',
#  'world\\t千姿百态 的 一年一度 委内瑞拉 盛大 同性恋 游行 ！\n',
#  'finance\\t道 达 投资 手记 ： 反弹 行情 咋 走 ？ 只有 成交量 会 说 真话\n',
#  'society\\t夫妻 吵架 阳台 扔下 2 万 钞票 事后 去 捡钱 只 剩 100 元\n',
#  'military\\t从 “ 英雄城 ” 走向 “ 主战场 ”\n',
#  'society\\t社保 、 公积金 、 养老 、 医疗 ！ 太原人 最 关心 的 20 个 问题 都 在 这 ！\n',
#  'sports\\t李铁 亲自 赶往 北京 ， 当 面向 郭炳颜 道歉\n',
#  'car\\t男子 从 废品站 拉 回 一辆 报废 汽车 ， 一番 动手 之后 竟 变成 帅气 越野车\n',
#  'food\\t致 青春 — — 那些 年 我们 在 大学 吃 过 的 饭菜 ！\n',
#  'travel\\t不能 小看 那些 部落 原住民\n',
#  'world\\t高考 那点 事 ： 俄 85 岁 老人 成为 最 年长 高考 考生\n',
#  'car\\t自动挡 怎么 开 划算 ， 这 6 个 误区 千万 别碰\n',
#  'world\\t实习 屡遭 拒告 政府 歧视 澳洲 华裔 医生 获赔 4 万澳元\n',
#  'world\\t退欧 ， 英国 害 了 自己 ， 也 连累 了 他人\n',
#  'society\\t发现 女友 银行卡 上 有 八十万 存款 ， 听 完 她 的 解释 ， 我 泪流满面 ！\n',
#  'entertainment\\t传 SMAP 香取 慎 吾 或 退出 娱乐圈 恐 变成 四人 组合\n',
#  'entertainment\\t霍 建华 林心如 拍 婚纱照 ， 你 以为 胡歌 火 了 ， 其实 是 他\n',
#  'baby\\t一位 妈妈 的 自诉 ： 妈妈 越懒 ， 孩子 成绩 越 好 ！ 说 得 真 好 ， 家长 必看 ！\n',
#  'entertainment\\t《 超 少年 密码 》 曝 人物 海报 TFBOYS 亮相\n',
#  'car\\t宾利 将 推 全新 双座 跑车 或 定名 Barnato\n',
#  'society\\t社保 缴费 基数 上调 ， 影响 有 多 大\n',
#  'finance\\t鳜鱼 混养 河蟹 需注意 五个 问题\n',
#  'car\\t自由 光卖 得 好 ： 是 情怀 还是 配置 ？ 其实 是 价格\n',
#  'entertainment\\t《 倚天 屠龙记 》 四美 都 嫁 了 心疼 我 还 单着 的 无忌 哥哥\n',
#  'tech\\tMIUI7 使命 终于 结束 ， 小米 3 用户 还 能 刷 最后 一个 开发 版\n',
#  'car\\t20 年老 教练 经验 ： 发动机 的 起步 和 关闭 必须 注意 的 要点\n',
#  'tech\\t俄罗斯 工程师 忘 关门 ， 机器人 逃跑 40 分钟 导致 交通堵塞\n',
#  'entertainment\\t亲爱 的 翻译官 小说 乔菲得 了 什么 病乔菲 为了 程家 阳 堕胎\n',
#  'world\\t纽约 华埠 现 模式 盗窃案 嫌犯 七 闯 民宅 偷 财物\n',
#  'finance\\t运营 500 艘 船 ， 15 亿美金 造新船 ， 掀开 神秘 船东 的 面纱\n',
#  'game\\t画风 陡变 ！ 《 战神 》 和 《 战神 3 》 重 制版 画面 对比\n',
#  'essay\\t我 想 ， 你 应该 记得 我\n',
#  'world\\t他 是 黑帮 教父 拯救 了 无数 小混混 大 毒枭 都 听 他 的 ！\n',
#  'finance\\t欧莱雅集团 香港 多店 遭 抗议 集体 关闭 连 雀巢 都 躺 枪\n',
#  'world\\t“ 美国 第一 能源 计划 ” ： 特朗普 终究 还是 被 自己 的 无知 出卖 了\n',
#  'world\\t微观 天下 ： 孔雀 太 爱美 跑 到 洗手间 照镜子\n',
#  'discovery\\t中国 一 尖端科技 世界 上 无人 可 破解 ， 美国 感慨 这个 装备 我们 都 还 没有\n',
#  'society\\t的哥 拒载 轮椅 老人 ， 他 说 ： 罚款 扣分 事小 ， 出现意外 事大\n',
#  'sports\\t格林 日记 : 我 和 水花 表现 很糟 下一场 要 当成 战争\n',
#  'tech\\t直击 ： 自 媒体 成功 运营 之道\n',
#  'car\\t突然 不想 做 一个 安静 的 美男子\n',
#  'car\\t宝马 8 系 “ 复出 ” 了 6 年 ， 这次 应该 是 真的\n',
#  'travel\\t四条 火车 让 你 走遍 祖国 大江南北 ， 一起 感受 大美 中华\n',
#  'game\\t必看 的 守望 国际 赛 只是 主播 满足 了 ？ 虎牙 领衔 暑期\n',
#  'game\\t20 年前 就 推出 VR 的 任天堂 ， 对 VR 无动于衷 ？\n',
#  'car\\t买 新 不 买 旧 ， 10 万 最 值得 买 的 家 轿 ！\n',
#  'tech\\t科普 | VR 运动 追踪 技术 101\n',
#  'tech\\t看 完 你 就 明白 了 ， 交流电 是 如何 变成 直流电 的\n',
#  'tech\\t俄罗斯 一头 机器人 成功 " 逃出 " 实验室\n',
#  'sports\\t在 里 约 死亡 之组 眺望 八强 席位 ， 学霸 邵婷 博士 将成 中国女篮 关键人物\n',
#  'sports\\t梅西 胜诉 ！ 告 西班牙 报纸 恶意 诽谤 说 他 吃 兴奋剂\n',
#  'entertainment\\t王力宏 首秀 获封 拼命 暖 男大秀 尴尬 冷 幽默\n',
#  'fashion\\t上海 电影节 | 范冰冰 刘亦菲 唐嫣 舒淇 刘涛 一块 走红 毯 谁 最美 ？\n',
#  'society\\t这种 所谓 的 “ 人参果 ” ， 能 不吃 就 不吃 ， 没 啥意思 ！\n',
#  'military\\t伊朗 空军 一架 苏 - 24 战机 坠毁 飞行员 成功 弹跳\n',
#  'entertainment\\t胡杏儿 结婚 半 周年 高调 告白 老公 ： 爱 你 一万年\n',
#  'car\\t只想 省点 油 ， 又 害怕 双 离合 、 直喷 有 风险 ， 到底 咋整 ？\n',
#  'baby\\t生 孩子 期间 发生 惊魂 一幕 ， 事后 医生 们 都 接近 瘫痪 ！\n',
#  'sports\\t必看 ！ 2017 年初 AirJordan 发售 清单 曝光\n',
#  'sports\\t火箭 与 哈登 重新 谈判 4 年 1.18 亿美元 留队\n',
#  'society\\t你 有 “ 东汉 末年 ” 驾照 也 没用 ， 违法 照样 处罚 ！\n',
#  'travel\\t有山有水 有 凉风 ， 夏季 旅游 到 这里\n',
#  'discovery\\t如果 地球 更 靠近 银河系 中心 会 怎样 ？\n',
#  'sports\\t罗斯 博格 无线电通信 完整版 若 受罚 将 只 领先 1 分\n',
#  'car\\t发动机 助力 中国 品牌 回顾 三菱 在 华之路\n',
#  'car\\t这 几款 国产车 的 外形 实在 是 好看 ， 论 外观设计 它们 可以 媲美 大牌 名车\n',
#  'world\\t委内瑞拉 食糖 短缺 迫使 可口可乐 停产\n',
#  'tech\\t王石 最终 还是 逃不了 ， 谁 都 超越 不了 马云 创建 的 支付宝\n',
#  'entertainment\\t杨幂 拍 古装戏 被 网友 偶遇 了 ， 这 造型 看起来 得 有 40 岁\n',
#  'world\\t国平 ： 为 完善 全球 治理 贡献 中国 智慧\n',
#  'history\\t《 水浒传 》 中 他 非常 器重 林冲 ， 后来 却成 了 林冲 最大 的 仇人 ！\n',
#  'history\\t大清 为什么 灭亡 ？ 你 不得 不知 的 真相 ！\n',
#  'tech\\t忘却 网盘 ， 用铁威 马 守卫 自己 的 那 一片 追求 一份 经典 一部 电影\n',
#  'car\\t这才 叫 大 改款 嘛 吉利 远景 SUV 实拍 图解\n',
#  'society\\t可怕 ！ 路上 遇到 这 情况 必定 不要 盲目 下车 ， 更 不能 离开 孩子 ！\n',
#  'game\\tE32016 贝 塞斯 达 发布会 前瞻 ： 神秘 、 还是 神秘 ！\n',
#  'society\\t偷房 本 雇 演员 冒充 房主 卖房\n',
#  'tech\\t智能 冰箱 销量 猛增 ？ 倾听 消费者 的 声音\n',
#  'society\\t合安 、 郑阜 高铁 初步设计 获批 ， 安九 高铁 预计 下半年 开建\n',
#  'car\\t丰田 这款 车冲沙 越野 样样 在 行 ， 想 买 的 人 很多 就是 价格 有点 贵\n',
#  'sports\\t湖人 哭 晕 ! 猛龙 黑金刚 将 留队 先 等 德罗 赞 谈完\n',
#  'history\\t用 张良 的 四个 故事 诠释 什么 叫 传奇 的 人生 | 原创\n',
#  'society\\t云南 暴雨成灾 昆明 可 看海 大理 云龙 路断 百车 被困\n',
#  'game\\t西山居 网龙 联合 制作 发行 《 魔域 手游 》\n',
#  'society\\t安徽 医改 重点 任务 下发 药企靠 “ 拼 费用 ” 恐难 生效\n',
#  'military\\t俄 近来 售华 武器 为什么 磕磕碰碰 出尔反尔 看 了 这些 就 会 明白\n',
#  'society\\t“ YBI 金融 互助 平台 ” 被 证实 “ 欺诈 ” 号称 每月 收益 30 %\n',
#  'finance\\tMSCI 、 深港 通 只是 噱头 ？ 还是 反弹 的 引燃 剂 ？\n',
#  'sports\\t詹姆斯 ： 欧文 ， 克利夫兰 现在 是 我 的 ， 但 终究会 是 你 的 ！\n',
#  'history\\t他 勇猛 不 在 关羽 、 赵云 之下 ， 为何 得不到 诸葛亮 的 重用 呢 ？\n',
#  'entertainment\\t超模 于娜 复出 街头 拍 写真 颜值 重回 巅峰\n',
#  'entertainment\\t陈 楚河 坐轮椅 现身 机场 口罩 遮面 神情 凝重\n',
#  'tech\\tVR 是 一个 过渡 产品 ， 但 他 通向 了 未来\n',
#  'sports\\t颤抖 吧 ！ 火箭 豪组 进攻 夺冠 阵容 ！ 宣布 进入 争冠 行列\n',
#  'world\\t关于 南海 仲裁 ， 这张 图说 得 比 谁 都 清楚\n',
#  'finance\\t互联网 + 卫星 导航 专业展 今 举行 北斗 导航 主题 基金 迎 机遇\n',
#  'entertainment\\t杰瑞 德 · 莱托 ： 一个 开挂 的 不 老 鲜肉 是 如何 养 （ 自 ） 成 （ 虐 ） 的\n',
#  'game\\t梦幻 西游 手游 秘境 积分 介绍 目标 第一名 冲刺\n',
#  'sports\\t为什么 新 衣服 买回来 一定 要 先洗 ？\n',
#  'tech\\t再次 斩获 Interop 东京 展 四项 金奖 ， 华为 厚积薄发 引领 新 ICT\n',
#  'tech\\t王思聪要 超越 他 爹 ， 可能 没戏 ！ 但 在 这 一点 上 ， 他 赢 了\n',
#  'history\\t他 是 袁世凯 帮凶 杜月笙 顾问 为何 周恩来 特批 其 加入 共产党 ？\n',
#  'history\\t她 13 岁入 宫 ， 嫁 过 两个 皇帝 ， 贤良 一生 ， 终成 太后\n',
#  'society\\t近期 又 开出 四张 网约车 平台 罚单\n',
#  'sports\\t科内 特 疑似 诈伤 拖延时间 没完 ！ 对手 将 选择 上诉\n',
#  'game\\t马云 爸爸 “ 打 脸记 ”\n',
#  'sports\\t头部 受 重击 留 后遗症 帕金森 困扰 拳王 阿里 30 余年\n',
#  'society\\t记者 调查 ： 裸持 借贷 的 背后\n',
#  'tech\\t聚合物 电池 ： 为啥 手机 都 用 而 充电 宝用 的 少 ？\n',
#  'sports\\t中甲 联赛 权健 VS 黄海 意大利 PK 西班牙 黄海 主力 门将 停赛\n',
#  'car\\tcar2go ： 重庆 每 1.7 分钟 就 有 一次 租赁\n',
#  'essay\\t一句 话 的 知音\n',
#  'history\\t知道 清朝 皇帝 谁 的 妃子 最多 吗 ？ 竟 有人 十四岁 为 他 生子\n',
#  'finance\\t出走 的 王石 ： 资本 不该 掣肘 人才 发展\n',
#  'travel\\t九 黄山 就是 这么 叼 ， 免 门票 啦 ！\n',
#  'tech\\t宝宝 心里 苦 — — 支付宝 强制 过节 的 背后 原因 是 什么 ？\n',
#  'story\\t担心 被 人 发现 ， 总裁 让 我 小声点\n',
#  'game\\t《 星际争霸 2 》 突变 痛苦 神庙 复仇 战士 BUFF 加成 方法\n',
#  'car\\t比亚迪 宋双 模版 将 于 下半年 正式 上市\n',
#  'car\\t不可 小视 如何 正确 使用 汽车 脚垫\n',
#  'entertainment\\t看 了 这 一家 ， 李小璐 会 不会 care ？\n',
#  'tech\\t马云下 一个 滴滴 帝国 ， 你 准备 好 被 颠覆 了 吗 ？\n',
#  'history\\t清宫 紫禁城 竟然 没 一个 厕所 ， 慈禧 老佛爷 如何 解决 内急 问题\n',
#  'society\\t荐 读 | 葡萄 挂 上 “ 身份证 ” ， 市民 吃 得 更 安心\n',
#  'game\\tLOL 解说 们 人物 漫画 ， 心塞 的 若风 默默 打上 了 0 分\n',
#  'entertainment\\t《 好 先生 》 江 疏影 睡颜王 孙红雷 齐 刘海 引热议\n',
#  'finance\\t田洪良 ： 美国 6 月 非农 来临 以 警惕 的 心来 对待\n',
#  'sports\\t中超 之父 在 他 任内 球场 从 爆满 到 无人问津\n',
#  'sports\\t威尔士 的 胜利 离不开 他 ： 自杀身亡 的 主帅 斯皮德\n',
#  'world\\t调查 人员 检验 埃航 失事 客机 黑匣子 冀 找出 空难 肇因\n',
#  'entertainment\\t伦敦 交通灯 上 小人 有 了 同 性伴侣 ， 这个 画风 有点 萌 ！\n',
#  'finance\\t商品 期货 已成 圈套\n',
#  'game\\t口袋妖怪 Go 国服 上线 有望 代理商 或是 腾讯\n',
#  'sports\\t奥运 筹备 进入 尾声 田径 跑道 五环 标志 绘制 完成\n',
#  'world\\t日本 的 中华 料理 是 日本 人 的 发明\n',
#  'tech\\t被盗 iPhone 背后 的 巨大 阴谋 ， 一条 黑色 产业链 已经 形成\n',
#  'history\\t革命 小 酒 天天 醉\n',
#  'tech\\t腾讯 应用 宝 启动 全新 代言人 ， 会 是 他 / 她 吗 ？\n',
#  'finance\\t一夜之间 欧美 股市 惨遭 血洗 ！\n',
#  'car\\t一秒钟 识别 轮胎 、 玻璃 的 出厂日期 ， 王语嫣 都 未必 知道 的 小 绝技\n',
#  'tech\\t长征 7 号 火箭 的 VR 元素 ， 让 你 见识 什么 叫 真正 的 工业 4.0\n',
#  'baby\\t南怀瑾 老师 ： 请准 父母 注意 了 ， 胎儿 的 胎毒 一定 要 挖 干净\n',
#  'history\\t古代 日本 什么 都 要学 中国 ， 唯独 不 学 这个 ， 是 什么 ？\n',
#  'military\\t俄 这次 赚 翻 了 ： 一年 光 武器 就 卖 快 两百亿 普京 确实 又 教 中国 一新 招\n',
#  'society\\t优秀 警察 是 " 失信 " 爸爸 8 岁 娃 : 你常 加班 , 但 我爱你\n',
#  'sports\\t世体 ： 若内 马尔 不 续约 ， 迪 巴拉 或是 B 方案\n',
#  'society\\t京津冀 1 小时 交通 圈 ， 燕郊 人 ， 究竟 受益 几何 ？\n',
#  'baby\\t宝宝 需要 绑腿 、 睡 头型 吗 ？\n',
#  'tech\\t与 阿里 村 淘 都 “ 干上 了 ” ， 淘 实惠 到底 踩 过 多少 坑 ？\n',
#  'society\\t学校 装修 后 学生 病亡 校方 被判 承担 赔偿 责任\n',
#  'society\\t讽刺 故事 ： 办 假证\n',
#  'sports\\t北爱 主帅 ： 要是 淘汰赛 能 碰 法国 那 就 太棒了\n',
#  'entertainment\\t你造 吗 ？ 这些 韩国 欧巴 都 有 一双 绅士 手\n',
#  'game\\t季中赛 反向 巡礼 · SKT ： 翱翔天际 的 王者\n',
#  'game\\t玩 魔兽 世界 那些 年 ， 我 被称作 网瘾 少年 ..\n',
#  'finance\\t钢厂 减产 检修 逐步 增多 钢价 下行 空间 有限\n',
#  'finance\\t由 新 材料 “ 十三 五 ” 规划 说 到 有色 、 石墨 烯\n',
#  'finance\\t* ST 盈方 ： 关于 股票 复牌 的 公告\n',
#  'tech\\t他 16 年前 穷困潦倒 ， 16 年 后 一手 打造出 个 5000 亿 的 微信 帝国\n',
#  'discovery\\t「 本周 太空 图 No . 50 」 冥王星 的 夜晚\n',
#  'sports\\t以老带 新 期待 双金 （ 奔 向 里 约 · 中国 军团 奥运 项目 扫描 （ 12 ） ）\n',
#  'game\\tDOTA2 今日 更新 ： 网络 信息 优化 ， 不朽 3 描述 ， 最强 至宝 对决\n',
#  'entertainment\\t三个 “ 林俊杰 ” 同台 演唱 《 修炼 爱情 》 ， 模仿 太像 完全 分不清 啊 ！\n',
#  'society\\t讲真 ， 朋友 圈里 没 朋友\n',
#  'tech\\t“ 神威 太湖 之光 ” 登顶 全球 超算 采用 自主 芯片\n',
#  'car\\t新迈腾 PK 沃尔沃 S60 谁 更 值得 拥有 呢\n',
#  'car\\t不 吹 不 捧 ， 奔驰 GLC 的确 是 辆 不错 的 SUV ！\n',
#  'sports\\t张玉宁 替补 进球 难 救主 ， 维特 斯 2 - 3 告负\n',
#  'game\\tLOL 友谊 的 娃娃车 说 翻 就 翻\n',
#  'entertainment\\t只 引领 ， 不 跟随 看 江苏 卫视 如何 示范 综艺 “ 新 ” 玩法\n',
#  'military\\t百艘 舰艇 南海 演兵\n',
#  'society\\t这样 的 90 后 美女 ， 简直 是 万人迷 ， 生活 工作 各种 美\n',
#  'entertainment\\tTAHITI 成员 Ari 拍 bnt 写真 水蓝 长裙 变 身 魅力 小 女人\n',
#  'tech\\t微商 必备 ! 电脑 多开 微信 的 三种 方式 ， 效率 直线 提升 ！\n',
#  'finance\\t学院派 的 气质 VC 北极光 交学费 悟出 “ 三不投 ” 原则\n',
#  'regimen\\t它 是 三高 疾病 的 克星 ， 一种 吃法 防治 一种 病 ， 不可 不知 ！\n',
#  'world\\t哥伦比亚 航空 一 客机 遭重 颠簸 空姐 悲剧 了\n',
#  'tech\\tvr . cn 近 千万元 成交 热门 行业 是 域名 发展 的 重要 因素\n',
#  'world\\t奥巴马 为 希拉里 站台 称 她 不会 羞于 动用 武力 保护 美国 \x7f\n',
#  'car\\t保时捷 panameraShootingbrake 假想 图 曝光\n',
#  'travel\\t展望 “ 十三 五 ” 系列报道 五 ： 发挥 罗浮山 龙头 作用 推动 中部 绿色 崛起\n',
#  'entertainment\\t真正 的 名媛 应该 是 这样 的 ！\n',
#  'fashion\\tab 红毯照 跟 老公 一样 高 了 ， 这 高跟鞋 至少 25cm 她 真 有 168 ？\n',
#  'game\\t即时战略 类 VR 新作 《 宇宙 之旅 》 正式 登陆 Steam ！\n',
#  'travel\\t西南 首个 高空 刺激 项目 公园 横空出世 ， 竟然 是 在 重庆 万盛 奥陶纪 ～ ～\n',
#  'car\\t小 海狮 也 有 大 内容 金旅 海狮 旅居 车 测评\n',
#  'car\\t买 新车 还 怕 买 到 瑕疵 旧车 吗 ？ 买车 时 这 几点 你 一定 要 看清楚\n',
#  'entertainment\\t集英社 否认 中国 公司 1510 万美元 购入 海贼王 真人 电影 拍摄 版权\n',
#  'car\\t东风 直追 江铃 第三 位置 将 不保 ！ 5 月 轻卡 排行 前十\n',
#  'sports\\t这一扣 见证 太空 易 归来 ！ 男篮 还有 谁 跟 他 一起 拼\n',
#  'entertainment\\t《 甄 嬛 传 》 浣 碧 PO 美照 ， 晒痕 明显 ， 网友 ： 你 一定 是 恋爱 了 ！\n',
#  'entertainment\\t网络 美少女 个个 “ 见光死 ” ？\n',
#  'discovery\\t物理学 咬文嚼字 之 七十七 ： 黑 、 暗 的 物理学\n',
#  'car\\t新瑞虎 3 掏心 掏肺 地 降价 增配 ， 但 它 有 一个 致命 的 缺点 ！\n',
#  'military\\t是 一场 政治 闹剧\n',
#  'sports\\t唐韦星 的 拼 和 太不容易 直指 冠军 的 作战 态势\n',
#  'world\\t中 美 最大 的 不同 就是 “ 不同 ”\n',
#  'world\\t湖北 国际 合作 新西兰 （ 奥克兰 ） 工作站 授牌 成立\n',
#  'tech\\t好消息 ！ 6 月 1 日 郑州 地铁 1 号线 将 推出 微信 支付宝 购票 啦 ~\n',
#  'entertainment\\t5 月 25 日 《 每日 文娱 播报 》 内容提要\n',
#  'society\\t七旬 夫妇 骑 电动车 被 撞 疑似 闯红灯 所致\n',
#  'society\\t别 再 买 了 ！ 质检 总局 公布 进口 食品 、 化妆品 “ 黑名单 ”\n',
#  'sports\\t我们 为什么 都 喜欢 夜钓 ？\n',
#  'car\\t看见 警车 我 就 紧张 ， 结果 就 撞 上去 了\n',
#  'sports\\t太极拳 说 .\n',
#  'sports\\t晨报 ： 纽卡 续约 贝尼特 斯 ， 皇马 将 续约 C 罗\n',
#  'sports\\t霸气 ！ 詹姆斯 向 骑士 球迷 喊 ： “ 要 为 你们 带回 总冠军 ” ！\n',
#  'society\\t西站 派出所 开展 禁毒 清查 活动\n',
#  'game\\t《 拳皇 14 》 饿狼 传说 队新图 “ 龙卷风 拳法 ” 好 炫酷 ！\n',
#  'finance\\t五图 显示 为什么 黄金 股 从来 没有 这么 便宜 过 ！\n',
#  'sports\\t贝尔 输球 不 开心 ？ 那 就 吃 吃 吃\n',
#  'tech\\t融资 1000 万 他 养 了 一群 机器人 宝宝 喂 数据 自动 出 结果 预测 银行 89 % 坏账\n',
#  'world\\t还 有完没完 ！ 美再 对华 铁制 传动件 作出 反倾销 初裁\n',
#  'society\\t如果 四川 、 山东 、 河南 、 江苏 真的 暴雨 ， 你 准备 好了吗 ？\n',
#  'game\\tDNF 练 号 狂人 32 个 角色 满级 拍照 留念 ！\n',
#  'game\\t用墨 菲 定律 看 皇室 战争 ： 游戏 的 疲惫感 与 成就 系统 的 败笔\n',
#  'entertainment\\t22 岁 就 有 了 胖 儿子 ！ 韩国 男团 前任 成员 当爹 后 画风 突变 ！\n',
#  'game\\t关于 《 守望 先锋 》 的 外挂 风波 ： 不是 不 报 ， 时候未到\n',
#  'society\\t王老吉 、 加多宝 29 亿 商标 案开庭\n',
#  'tech\\tVR / AR 行业 重新 洗牌 ： 微软 与 谷歌 的 平台 之争\n',
#  'tech\\t“ 老奸巨猾 ” 的 郭台铭 摆 了 这个 日本公司 一道\n',
#  'society\\t芜湖 中山 桥 和 中 江桥 将 同步 拆除 具体 时间 已 定\n',
#  'sports\\t“ 勇士 英雄 ” 进入 最后 彩排 精彩 大战 一触即发\n',
#  'discovery\\t琥珀 中 封存 了 9900 万年 的 鸟翼\n',
#  'car\\t动力 强 综合 性价比 更高 外观 霸气 东风 这款 SUV 空间 够 大\n',
#  'society\\t一点 小剐 蹭 竟 群殴 车长\n',
#  'finance\\t中信证券 ： 中国 全面 宽松 已 过去 下半年 降息 无望\n',
#  'society\\t患 怪病 兄弟 白天 嬉戏 如常 夜晚 就 成 “ 植物 人 ”\n',
#  'society\\t碰瓷 新 玩法 传说 中 的 女司机\n',
#  'military\\t中国 远征军 ： 悲歌 缅甸 泣 忠魂 ， 荡平 滇寇 震 乾坤\n',
#  'entertainment\\t每当 看到 YG 家 的 whoisnext ？ 你 会 想到 啥 儿 ？\n',
#  'fashion\\t性感 的 镂空 连衣裙 这 样子 穿 才 不会 撩骚\n',
#  'entertainment\\t《 余罪 》 第三季 余罪 重返 帮派 解冰 变黑 警 ？ 网友 抽丝剥茧 的 脑洞 收 也 收 不住\n',
#  'society\\t车主 将车 停 在 路旁 数天 不取 ， 公路 施工队 直接 在 车轮 铺上 沥青\n',
#  'baby\\t全方位 提高 小儿 免疫力\n',
#  'food\\t夏日 小 清新 - - - 椰汁 马蹄 糕\n',
#  'sports\\t武汉 网球 公开赛 李娜 复出 亮相 ， 连 她 表弟 也 成 了 “ 华科 ” 校园 红 人\n',
#  'car\\t比缤智 更 便宜 的 SUV 来 了 本田 将 推出 小型 SUV9 万元 落地\n',
#  'sports\\t直击里 约 奥运 - 走过 路过 千万 不要 错过 之瓜 纳巴拉 湾\n',
#  'tech\\t盘点 | 《 独立 日 ： 卷土重来 》 十大 黑 科技\n',
#  'game\\tUzi 直播 小 插曲 mata 内裤 出镜 到底 发生 了 什么 ！\n',
#  'world\\t全球 聚焦 ： 卡梅伦 挥泪 ， 再见 欧盟\n',
#  'car\\t二手车 行业 里面 都 有 什么 黑话 ？\n',
#  'tech\\t把 理想 变成 现实 谷歌 重启 多个 老 项目\n',
#  'sports\\t他 曾 是 球队 绝对 主力 远 赴 恒大后 为何 被 球迷 称为 “ 浪射王 ” ？\n',
#  'baby\\t家长 注意 ： 别 等 孩子 上 了 初中 才 后悔 ， 小学 语数外 ， 应该 这样 学 ！\n',
#  'entertainment\\t年纪轻轻 就 出道 的 漫画家 老师 们 真是 才华洋溢 啊 ～\n',
#  'entertainment\\t祸不单行 ！ “ 猪哥 亮 ” 节目 将 停播 ？\n',
#  'travel\\t一大 波 国际 主题乐园 向 中国 袭 来 ， 本土 主题乐园 大喊 “ 狼来了 ”\n',
#  'entertainment\\t穿 上 它 ， 阿娇 邓紫棋 吴昕 这些 粗腿 小天 后 都 有救 了\n',
#  'fashion\\t肌肉 腿 如何 挑选 高跟鞋\n',
#  'sports\\t每日 一黑 ： C 罗进 决赛 的 这 一天 ， 梅西 公布 了 自己 的 新 “ 球衣 ”\n',
#  'world\\t马朝旭 ： 中国 坚持 不 接受 不 参与 菲 单方面 提起 的 南海 仲裁 案\n',
#  'society\\t执行 风暴 ： 开豪车 当 老赖 坑惨 亲姐妹\n',
#  'sports\\t昔日 总冠军 成员 或 重回 勇士 暗示 正在 进行 商谈\n',
#  'game\\t原创 | 乐动 卓越 邢山虎 《 我 叫 MT3 》 成为 回合制 和 天卡制 后 的 思考\n',
#  'car\\t宝马 空档 踩油门 伤车 吗 ？ 空档 滑行 伤车 吗 ？ 省油 吗 ？\n',
#  'tech\\t这个 机械 小白 给 自己 造 了 个 木工 车床\n',
#  'car\\t起动机 异响 原因 及 诊断\n',
#  'entertainment\\t接 代言 接到 手软 的 欧巴 ： 宋仲基 2016 年代 言 大盘 点\n',
#  'society\\t银行卡 在 手中 却 被盗 刷十笔 没收 到 短信 提醒\n',
#  'baby\\t宝贝 被 蚊子 叮咬 以后 ， 90 % 的 妈妈 都 做 错 了\n',
#  'sports\\t翘着 二郎腿 却 尽显 完美 身材 的 气质 美女 ， 修长 玉腿 性感 高 跟 ， 小 尤物\n',
#  'sports\\t精彩 回顾 | 葡萄牙 夺得 欧洲杯 ！ 31 岁 的 老 男孩 C 罗 ， 弥补 了 12 年前 的 遗憾\n',
#  'entertainment\\t佟丽娅 晒 甜美 自拍 网友 ： 谁家 少女 又 跑 出来 了 ？\n',
#  'tech\\tAccess 还是 Excel ， 用 谁 更 合适 ？\n',
#  'sports\\t国米 新 董事会 下周 成立 张 近东 之子 或 任新 主席\n',
#  'entertainment\\t都 说 公司 只 捧 泫 雅 ， 那 是因为 其他人 怎么 捧 都 捧 不 红 吧\n',
#  'car\\t国产车 不配 讲 性能 ？ 有些 车分 分钟 让 跑车 吃 灰\n',
#  'military\\t越南 却 购买 最强 雷达 专门 提防 中国 歼 20 最新 涂层 受到 考验\n',
#  'baby\\t宝宝 的 粥 里 别 再 放 这 4 样 东西 ， 不仅 无益 还会 影响 身体\n',
#  'society\\t9 旬 抗战 老兵 公园 乞讨 官方 : 不符 优抚 政策\n',
#  'sports\\t麦蒂 相信 KD 胡子 诅咒 存在 始作俑者 称有法 化解\n',
#  'tech\\t京东 ： 满 减券 的 背后\n',
#  'car\\t2016 款 特斯拉 ModelSP85D 优雅 如 绅士\n',
#  'society\\t盘点 那些 出境 旅游 被 遣返 的 十大 奇葩 理由 ！\n',
#  'society\\t你 还 在 陌生 群里 玩 微信 红包 接龙 ？ 谨防 落入 赌博 陷阱\n',
#  'car\\t你 知道 吗 ？ 比亚迪 S8 是 跑车\n',
#  'history\\t采生 折割 ： 一个 经典 谣言 的 制作 与 消散\n',
#  'world\\t李克强 将 于 7 月 13 日至 14 日 对 蒙古国 进行 正式 访问\n',
#  ...]

# %%
# 对载入数据进行预处理
# 分割类别标签和预测文本
labels1,labels2,text1,text2=[],[],[],[]
split_data1=[i.split(r'\t') for i in data1]
for i in split_data1:
    if len(i)==2:
        labels1.append(i[0])
        text1.append(i[1])
# labels1=[i[0] for i in split_data1]
# text1=[i[1] for i in split_data1]

split_data2=[i.split(r'\t') for i in data2]
for i in split_data2:
    if len(i)==2:
        labels2.append(i[0])
        text2.append(i[1])
# labels2=[i[0] for i in split_data2]
# text2=[i[1] for i in split_data2]
len(labels1),len(text1)
# Out:
# (334492, 334492)

# %%
# 对格式化的数据进行表格化
# 用pandas创建一个两列的表格，第一列为类别标签，第二列为文本，默认无表头。
train_df=pd.DataFrame([i,j] for i,j in zip(labels1,text1))
eval_df=pd.DataFrame([i,j] for i,j in zip(labels2,text2))

# %%
# 检视数据。
train_df[0][:10]
# Out:
# 0          society
# 1            world
# 2    entertainment
# 3              car
# 4             baby
# 5           sports
# 6             tech
# 7          society
# 8         military
# 9    entertainment
# Name: 0, dtype: object

# %%
# 标签数值化
# sklearn.preprocessing.LabelEncoder()：标准化标签，将标签值统一转换成range(标签值个数-1)范围内。
le=preprocessing.LabelEncoder()
le.fit(np.unique(train_df[0].tolist()))
print('标签值标准化:%s' % le.transform(["world", "entertainment", "car", "baby","entertainment"]))
print('标准化标签值反转:%s' % le.inverse_transform([0, 2 ,0 ,1 ,2]))
# Out:
# 标签值标准化:[17  3  1  0  3]
# 标准化标签值反转:['baby' 'discovery' 'baby' 'car' 'discovery']

# %%
#
train_df[2] = train_df[0].apply(lambda x:le.transform([x])[0])
eval_df[2] = eval_df[0].apply(lambda x:le.transform([x])[0])

del train_df[0]
del eval_df[0]

# %%
# 统计不重复的标签数量。
num_labels=len(np.unique(train_df[2].tolist()))
num_labels
# Out:
# 18

# %%
# 保存预处理后的训练数据。只有前面加上r之后才能保存到内嵌文件夹
train_df.to_csv(r'data\muti_class1776\train_data.csv',header=False,sep='\t',index = False)
eval_df.to_csv(r'data\muti_class1776\test_data.csv',header=False,sep='\t',index = False)

# %%
# 检视预处理后的训练数据。
train_df.head()
# Out:
#                                                  1   2
# 0                  陆家嘴 不 雅 视频 曝光 ： 系恶 “ 性 ” 营销 ？\n  12
# 1  日本 冲绳 民众 举行 大规模 抗美 集会 活动 冲绳 县知事 : 希望 改变 政治 结构\n  17
# 2                 林心如 全黑 连体 装 现身 ， 被 赞比 模特 身材 更好\n   3
# 3                                   别克 逆 生长 实验 型\n   1
# 4   你 的 宝宝 到底 需不需要 补锌 ？ 又 该 如何 补充 ？ （ 内附 补锌 食谱 ）\n   0

# %%
# 检视预处理后的验证数据。
eval_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47784 entries, 0 to 47783
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       47784 non-null  object
#  1   2       47784 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 746.8+ KB

# %% [markdown]
# # 构建分配模型
# ### 从应用落地的角度来说，bert虽然效果好，但有一个短板就是预训练模型太大，预测时间在平均在300ms以上（一条数据），无法满足业务需求。知识蒸馏是在较低成本下有效提升预测速度的方法。
# ### 在不丧失精度和预测效果的前提下，为了提高预测时的速度，以及节省空间，此处载入的是BERT的“蒸馏版” --- distibert，这是一种能够将大型BERT模型（被称为「老师」）压缩为较小模型（即「学生」）的技术。
# ## 原理：
# ### - 知识蒸馏：迁移泛化能力
# ### 知识蒸馏（有时也称为师生学习）是一种压缩技术，要求对小型模型进行训练，以使其拥有类似于大型模型（或者模型集合）的行为特征。这项技术由 Bucila 等人提出，并得到了 Hinton 等人的推广。我们这里采用的，正是 Hinton 采取的方法。
# ### 在监督学习领域，我们在训练分类模型时往往会利用对数似然信号实现概率最大化（logits 的 softmax），进而预测出正确类。在大多数情况下，性能良好的模型能够利用具有高概率的正确类预测输出分布，同时其它类的发生概率则接近于零。
# ### 但是，某些“接近于零”的概率要比其它概率更大，这在一定程度上反映出模型的泛化能力。
# ### 例如，把普通椅子误认为扶手椅虽然属于错误，但这种错误远比将其误认为蘑菇来得轻微。这种不确定性，有时被称为“暗知识”。
# ### 我们也可以从另一个角度来理解蒸馏——用于防止模型对预测结果太过确定（类似于标签平滑）。
#
# 这里使用的类是ClassificationModel，说明如下：
# * ClassificationModel*
# - class simpletransformers.classification.ClassificationModel (model_type, model_name, args=None, use_cuda=True)  该类用于文本分类任务。
# * Class attributes*
# - tokenizer: 使用的预训练tokenizer
# - model: 使用的预训练模型（BERT、RoBERTa、XLNet、XLM、DistilBERT、ALBERT等）
# - model_name: 预训练模型的名称或者本地模型所在路径（其中的模型文件必须为pytorch_nodel.bin）
# - device: 用于训练和评价的设备，cpu、gpu（cuda）或者tpu。
# - results: 模型的评价结果，以dictionary的形式存在
# - args: 用于training和evaluation的参数dict，形如args={'reprocess_input_data': True, 'overwrite_output_dir': True})
# - cuda_device(可选) : 默认为 -1. 用于指定使用哪个GPU
# * Parameters*
# - model_type: (必须) str - 使用的预训练模型的类型，当前支持BERT、RoBERTa、XLNet、XLM、DistilBERT、ALBERT、CamemBERT、XLM-RoBERTa、FlauBERT
# ### model_name: (必须) str - 预训练模型的名称或者本地模型所在路径（其中的模型文件必须为pytorch_nodel.bin）
# - num_labels (可选): 数据集中类别的数量
# - weight (可选):长度为num_labels（标签数量）的列表，其中包含要分配给每个标签以进行损耗计算的权重数值。
# - args: (可选) dict - 参数字典，形如args={'reprocess_input_data': True, 'overwrite_output_dir': True})
# - use_cuda: (可选) bool - 默认为 -1. 用于指定使用哪个GPU class methods
# - train_model(self, train_df, output_dir=None, show_running_loss=True, args=None, eval_df=None)
# * Returns*
# - result: 以Dictionary的形式呈现evaluation results. (即Matthews correlation coefficient, tp, tn, fp, fn)
# - model_outputs: eval_df中每一行的模型输出列表
# - wrong_preds: 与模型的每个错误预测相对应的InputExample对象列表

# %%
# 对于多标签分类, 需要将标签的类别数传递给num_labels这个参数 ，这里是18个类，故num_labels = 18
# num_labels=18
# model = ClassificationModel(
#     model_type='distilbert',
#     model_name=r"C:/Users/Eric/Desktop/github实现有趣的代码/已完成/Bert-Chinese-Text-Classification-Pytorch/bert_pretrain/pytorch_model.bin",
#     num_labels=num_labels, 
#     args={"reprocess_input_data":True,"overwrite_output_dir":True},# 对输入数据进行预处理# 可覆盖输出文件夹  
#     use_cuda=True,
#     )
model = ClassificationModel(
    "distilbert", 
    r"C:/Users/Eric/Desktop/github实现有趣的代码/已完成/Bert-Chinese-Text-Classification-Pytorch/bert_pretrain/pytorch_model.bin",
    num_labels=num_labels, 
    args={"reprocess_input_data": True,   # 对输入数据进行预处理
          "overwrite_output_dir": True}   # 可覆盖输出文件夹
    )
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-109-c15b9d74e89a> in <module>
#      13     num_labels=num_labels,
#      14     args={"reprocess_input_data": True,   # 对输入数据进行预处理
# ---> 15           "overwrite_output_dir": True}   # 可覆盖输出文件夹
#      16     )
#
# F:\Anaconda\lib\site-packages\simpletransformers\classification\classification_model.py in __init__(self, model_type, model_name, num_labels, weight, args, use_cuda, cuda_device, onnx_execution_provider, **kwargs)
#     178         config_class, model_class, tokenizer_class = MODEL_CLASSES[model_type]
#     179         if num_labels:
# --> 180             self.config = config_class.from_pretrained(model_name, num_labels=num_labels, **self.args.config)
#     181             self.num_labels = num_labels
#     182         else:
#
# F:\Anaconda\lib\site-packages\transformers\configuration_utils.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     327             config = BertConfig.from_pretrained('./test/saved_model/my_configuration.json')
#     328             config = BertConfig.from_pretrained('bert-base-uncased', output_attentions=True, foo=False)
# --> 329             assert config.output_attentions == True
#     330             config, unused_kwargs = BertConfig.from_pretrained('bert-base-uncased', output_attentions=True,
#     331                                                                foo=False, return_unused_kwargs=True)
#
# F:\Anaconda\lib\site-packages\transformers\configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     372             resolved_config_file = cached_path(
#     373                 config_file,
# --> 374                 cache_dir=cache_dir,
#     375                 force_download=force_download,
#     376                 proxies=proxies,
#
# F:\Anaconda\lib\site-packages\transformers\configuration_utils.py in _dict_from_json_file(cls, json_file)
#     454         Args:
#     455             json_file (:obj:`str`):
# --> 456                 Path to the JSON file containing the parameters.
#     457
#     458         Returns:
#
# F:\Anaconda\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
