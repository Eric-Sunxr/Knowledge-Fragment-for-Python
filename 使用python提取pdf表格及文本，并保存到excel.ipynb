# %% [markdown]
# # pdfplumber在github上有[英文官方文档](https://www.baidu.com/link?url=QDXeAmZUwlkKMIGNcMTE4CAj_bR5oAEU8tO9O88EfI5mWbtG-BnXiilzUyM5dCRq&wd=&eqid=f22579e5002748e20000000260573ecf)

# %%
# 导入pdfplumber
import pdfplumber

# 读取pdf文件，保存为pdf实例
pdf =  pdfplumber.open("data/nba4.pdf") 

# 访问第二页
first_page = pdf.pages[1]

# 自动读取表格信息，返回列表
table = first_page.extract_table()

table
# Out:
# [['排名', '球队', '场数', '得分', '篮板', '助攻', '抢断', '盖帽', '犯规'],
#  ['1', '犹他 爵士', '32', '116', '48.4', '23.7', '6.3', '5.6', '18.8'],
#  ['2', '密尔沃基 雄鹿', '33', '120.1', '48.3', '26.2', '8.2', '4.8', '18.1'],
#  ['3', '纽约 尼克斯', '33', '104.7', '47.1', '20.9', '6.5', '4.8', '21'],
#  ['4', '奥兰多 魔术', '33', '104.8', '46.8', '22.5', '7.1', '4.3', '16.9'],
#  ['5', '新奥尔良 鹈鹕', '32', '115.5', '46.1', '25.3', '7.5', '4', '17.5'],
#  ['6', '费城 76人', '33', '113.9', '45.8', '23.3', '8.5', '6.1', '20'],
#  ['7', '亚特兰大 老鹰', '32', '113.7', '45.4', '24.4', '6.8', '4.8', '20'],
#  ['8', '洛杉矶 湖人', '33', '111.5', '45.2', '24.7', '7.1', '6.2', '18.6'],
#  ['9', '圣安东尼奥 马刺', '28', '110.7', '45.1', '25', '7.3', '5', '17'],
#  ['10', '俄克拉荷马城 雷霆', '32', '106.7', '44.7', '23.2', '7.1', '4.3', '18.3'],
#  ['11', '华盛顿 奇才', '30', '114.5', '44.6', '25.1', '7.4', '3.6', '22'],
#  ['12', '孟菲斯 灰熊', '28', '110.8', '44.6', '27.4', '9.6', '4.4', '18.5'],
#  ['13', '波特兰 开拓者', '31', '114.8', '44.5', '19.9', '7.2', '5.1', '19.7'],
#  ['14', '芝加哥 公牛', '31', '115.3', '44.3', '26.2', '7.2', '4.4', '20.3'],
#  ['15', '夏洛特 黄蜂', '31', '111.3', '44.3', '26.9', '8', '4.7', '18.5'],
#  ['16', '洛杉矶 快船', '34', '115.2', '44.2', '24.2', '7.2', '4.5', '19'],
#  ['17', '菲尼克斯 太阳', '31', '113.5', '43.8', '26.6', '6.4', '4.3', '20.1'],
#  ['18', '波士顿 凯尔特人', '32', '110.7', '43.8', '22.1', '8.2', '5.1', '21.2'],
#  ['19', '布鲁克林 篮网', '34', '121.4', '43.7', '27', '6.6', '5.4', '19.2'],
#  ['20', '金州 勇士', '33', '114.2', '43.5', '27.8', '7.8', '5.2', '21.8'],
#  ['21', '丹佛 掘金', '32', '115.2', '43.4', '26.3', '8.3', '4.4', '19.7'],
#  ['22', '克利夫兰 骑士', '33', '104.3', '43.4', '23.4', '8.3', '5.3', '19.2'],
#  ['23', '休斯顿 火箭', '30', '108.6', '43.3', '22.8', '8', '5.7', '20.1'],
#  ['24', '明尼苏达 森林狼', '33', '108.2', '43', '25.4', '8.5', '5.7', '21.7'],
#  ['25', '印第安纳 步行者', '30', '113.2', '42.8', '26.6', '8.4', '6.1', '20.6'],
#  ['26', '底特律 活塞', '32', '108', '42.7', '24.2', '7.8', '5.1', '20.7'],
#  ['27', '萨克拉门托 国王', '32', '114.1', '42.6', '25.7', '6.8', '5', '19.8'],
#  ['28', '达拉斯 独行侠', '31', '111.9', '42.6', '22.5', '6.3', '4.5', '20.8'],
#  ['29', '迈阿密 热火', '32', '107.2', '42.6', '26.1', '6.9', '3.9', '19.8'],
#  ['30', '多伦多 猛龙', '33', '112.6', '41.7', '25', '8.7', '5.6', '22']]

# %% [markdown]
# 第二步：整理成dataframe格式，保存为excel

# %%
import pandas as pd

# 将列表转为df
table_df = pd.DataFrame(table[1:],columns=table[0])

# 保存excel
table_df.to_excel('data/test.xlsx')

table_df
# Out:
#     排名         球队  场数     得分    篮板    助攻   抢断   盖帽    犯规
# 0    1      犹他 爵士  32    116  48.4  23.7  6.3  5.6  18.8
# 1    2    密尔沃基 雄鹿  33  120.1  48.3  26.2  8.2  4.8  18.1
# 2    3     纽约 尼克斯  33  104.7  47.1  20.9  6.5  4.8    21
# 3    4     奥兰多 魔术  33  104.8  46.8  22.5  7.1  4.3  16.9
# 4    5    新奥尔良 鹈鹕  32  115.5  46.1  25.3  7.5    4  17.5
# 5    6     费城 76人  33  113.9  45.8  23.3  8.5  6.1    20
# 6    7    亚特兰大 老鹰  32  113.7  45.4  24.4  6.8  4.8    20
# 7    8     洛杉矶 湖人  33  111.5  45.2  24.7  7.1  6.2  18.6
# 8    9   圣安东尼奥 马刺  28  110.7  45.1    25  7.3    5    17
# 9   10  俄克拉荷马城 雷霆  32  106.7  44.7  23.2  7.1  4.3  18.3
# 10  11     华盛顿 奇才  30  114.5  44.6  25.1  7.4  3.6    22
# 11  12     孟菲斯 灰熊  28  110.8  44.6  27.4  9.6  4.4  18.5
# 12  13    波特兰 开拓者  31  114.8  44.5  19.9  7.2  5.1  19.7
# 13  14     芝加哥 公牛  31  115.3  44.3  26.2  7.2  4.4  20.3
# 14  15     夏洛特 黄蜂  31  111.3  44.3  26.9    8  4.7  18.5
# 15  16     洛杉矶 快船  34  115.2  44.2  24.2  7.2  4.5    19
# 16  17    菲尼克斯 太阳  31  113.5  43.8  26.6  6.4  4.3  20.1
# 17  18   波士顿 凯尔特人  32  110.7  43.8  22.1  8.2  5.1  21.2
# 18  19    布鲁克林 篮网  34  121.4  43.7    27  6.6  5.4  19.2
# 19  20      金州 勇士  33  114.2  43.5  27.8  7.8  5.2  21.8
# 20  21      丹佛 掘金  32  115.2  43.4  26.3  8.3  4.4  19.7
# 21  22    克利夫兰 骑士  33  104.3  43.4  23.4  8.3  5.3  19.2
# 22  23     休斯顿 火箭  30  108.6  43.3  22.8    8  5.7  20.1
# 23  24   明尼苏达 森林狼  33  108.2    43  25.4  8.5  5.7  21.7
# 24  25   印第安纳 步行者  30  113.2  42.8  26.6  8.4  6.1  20.6
# 25  26     底特律 活塞  32    108  42.7  24.2  7.8  5.1  20.7
# 26  27   萨克拉门托 国王  32  114.1  42.6  25.7  6.8    5  19.8
# 27  28    达拉斯 独行侠  31  111.9  42.6  22.5  6.3  4.5  20.8
# 28  29     迈阿密 热火  32  107.2  42.6  26.1  6.9  3.9  19.8
# 29  30     多伦多 猛龙  33  112.6  41.7    25  8.7  5.6    22

# %% [markdown]
# ## pdfplumber简介
# 前面已经介绍过pdfplumber的用途，也用一个小案例展示了如何提取表格，我觉得对于pdfplumber只需要了解三点就可以。
# - 1、它是一个纯python第三方库，适合python 3.x版本
# - 2、它用来查看pdf各类信息，能有效提取文本、表格
# - 3、它不支持修改或生成pdf，也不支持对pdf扫描件的处理
#
# Github地址https://github.com/jsvine/pdfplumber
#
# ## pdfplumber简单使用
# pdfplumber中有两个基础类，PDF和Page。看字面意思能猜出，前者是处理整个文档，后者是处理页面。
#
# **「pdfplumber.PDF类」**
#
# |属性|描述|
# |----|----|
# |.metadata|获取pdf基础信息，返回字典|
# |.pages|一个包含pdfplumber.Page实例的列表，每一个实例代表pdf每一页的信息。|
#
# **「pdfplumber.Page类」**
#
# 这是pdfplumber的核心功能，对pdf的大部分操作都是基于这个类，包括提取文本、表格、尺寸等。
#
# 这里暂不一一列举它的属性和方法。
#
# 通过一个简单的案例，就可以明白它们的作用。示例pdf文档，共两页：

# %%
# 1. 读取pdf
import pdfplumber

# 读取pdf文件，返回pdfplumber.PDF类的实例
pdf = pdfplumber.open("data/paper.pdf")

# %%
# 2. 获取该pdf文档的信息
pdf.metadata
# Out:
# {'CreationDate': "D:20201216102222+08'00'",
#  'Creator': 'TeX',
#  'ModDate': "D:20210106153849-08'00'",
#  'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020/W32TeX) kpathsea version 6.3.2',
#  'Producer': 'pdfTeX-1.40.21',
#  'Subject': 'AAAI-21',
#  'TemplateVersion': '2021.1',
#  'Title': 'PRELIMINARY VERSION DO NOT CITE',
#  'Trapped': 'False'}

# %% [markdown]
# 这些是pdf的基础信息，包括作者、来源、日期等。

# %%
# 3. 总页数
# 通过pdfplumber.PDF类的metadata属性获取pdf页数
len(pdf.pages)
# Out:
# 9

# %%
# 4. 读取第一页的页宽、页高等信息
# 第一页pdfplumber.Page实例
first_page = pdf.pages[0]

# 查看页码
print('页码：',first_page.page_number)

# 查看页宽
print('页宽：',first_page.width)

# 查看页高
print('页高：',first_page.height)
# Out:
# 页码： 1
# 页宽： 612
# 页高： 792

# %%
# 5. 读取第一页的文本
# 读取文本
text = first_page.extract_text()
print(text)
# Out:
# PRELIMINARY VERSION: DO NOT CITE
# The AAAI Digital Library will contain the published
# version some time after the conference
# Detecting Adversarial Examples from Sensitivity Inconsistency of
# Spatial-Transform Domain
# JinyuTian,1 JiantaoZhou,1,* YuanmanLi,2 JiaDuan1
# 1StateKeyLaboratoryofInternetofThingsforSmartCity,
# DepartmentofComputerandInformationScience,UniversityofMacau
# 2GuangdongKeyLaboratoryofIntelligentInformationProcessing,
# CollegeofElectronicsandInformationEngineering,ShenzhenUniversity
# {yb77405,jtzhou}@um.edu.mo,yuanmanli@szu.edu.cn,xuelandj@gmail.com
# Abstract Thoughmanyrobustclassiﬁcationstrategieshavebeenpro-
# posed,mostofthemarestillnotpowerfulenoughtodefeat
# Deep neural networks (DNNs) have been shown to be vul-
# the secondary attack or AEs generated by some advanced
# nerableagainstadversarialexamples(AEs),whicharemali-
# attacks e.g., C&W (Carlini and Wagner 2017). In fact, in
# ciously designed to cause dramatic model output errors. In
# (Tsiprasetal.2019),itwaspointedoutthatthetruerobust-
# thiswork,werevealthatnormalexamples(NEs)areinsen-
# ness would lead to depreciation in accuracy. Alternatively,
# sitive to the ﬂuctuations occurring at the highly-curved re-
# gionofthedecisionboundary,whileAEstypicallydesigned a weaker version of the defense is just to detect the AEs,
# over one single domain (mostly spatial domain) exhibit ex- while not ambiguously rectifying the classiﬁcation results.
# orbitant sensitivity on such ﬂuctuations. This phenomenon In many practical applications, such detection is still quite
# motivates us to design another classiﬁer (called dual clas- meaningful,generatingalarmingsignalstopotentialthreats.
# siﬁer) with transformed decision boundary, which can be Further,theAEdetectioncouldguideabetterdefensestrat-
# collaboratively used with the original classiﬁer (called pri- egy(Sunetal.2020).
# malclassiﬁer)todetectAEs,byvirtueofthesensitivityin-
# AnAEcanberegardedasthetranslationofanormalex-
# consistency.Whencomparingwiththestate-of-the-artalgo-
# rithms based on Local Intrinsic Dimensionality (LID), Ma- ample (NE) along the adversarial direction. Geometrically,
# halanobis Distance (MD), and Feature Squeezing (FS), our the adversarial direction usually points toward the highly-
# proposed Sensitivity Inconsistency Detector (SID) achieves curved region of the decision boundary, such that the deci-
# improved AE detection performance and superior general- sion boundary can be crossed with the minimized pertur-
# izationcapabilities,especiallyinthechallengingcaseswhere bation magnitude (Fawzi et al. 2018). A symmetric phe-
# theadversarialperturbationlevelsaresmall.Intensiveexper- nomenonwewouldliketopointoutisthatifwecaninten-
# imentalresultsonResNetandVGGvalidatethesuperiority
# tionally cause ﬂuctuations at the highly-curved regions
# oftheproposedSID.
# ofthedecisionboundary,thenthoseAEscouldeasilylead
# to different classiﬁcation results, while NEs would exhibit
# quite consistent behavior. Such phenomenon reveals that,
# Introduction
# forNEsandAEs,thereexistsaninconsistencyofsensitivity
# Deep neural networks (DNNs) have achieved the state-of- to boundary ﬂuctuation at highly-curved regions. This mo-
# the-artperformanceonawiderangeoftasksincludingim- tivates us to design another classiﬁer with transformed de-
# ageclassiﬁcation(Krizhevsky,Sutskever,andHinton2012), cisionboundary,whichcanbecollaborativelyusedwiththe
# speechrecognition(Karpathyetal.2014),etc.However,re- original classiﬁer (called primal classiﬁer) to detect AEs,
# centstudieshaveshownthatDNNsarevulnerabletocrafted by virtue of the sensitivity inconsistency. Ideally, the de-
# adversarialexamples(AEs),whicharegenerallyimpercep- signedclassiﬁer(calleddualclassiﬁer)shouldhavedissim-
# tibletothesenseofhumanitywhilebeingabletocausese- ilar structures at the highly-curved regions with the primal
# veremodeloutputerrors.Suchvulnerabilityleadstoserious classiﬁer, while maintaining similar structures at the other
# security risks when deploying DNNs on critical scenarios, regions.
# e.g.,self-drivingcars.Theattemptsfordefendingagainstthe
# Todesignthedualclassiﬁersatisfyingtheaboverequire-
# threatofAEscanberoughlycategorizedintotwotypes:ro-
# ments, we resort to the transform domain techniques, i.e.,
# bustclassiﬁcationandAEdetection.Theformertypeaimsto
# designtheclassiﬁeroverthetransformdomain,ratherthan
# eliminatetheimpactoftheadversarialnoiseandmakecor-
# the traditional spatial domain. In fact, some existing works
# rect classiﬁcation (e.g., adversarial training (Schmidt et al.
# (Liu et al. 2016; Trame`r et al. 2017) pointed out that mod-
# 2018), denoising, (Liao et al. 2018; Akhtar, Liu, and Mian
# els trained on the same feature domain of a given dataset
# 2018), defensive distillation (Papernot et al. 2016b), etc.).
# tendtoproducesimilardecisionboundaries,especiallytheir
# curved regions. This would explain why AE has the abil-
# *Thecorrespondingauthor.
# Copyright©2021,AssociationfortheAdvancementofArtiﬁcial ity of transferable attack on models with different archi-
# Intelligence(www.aaai.org).Allrightsreserved. tectures. More speciﬁcally, we construct the dual classiﬁer

# %%
# 6.读取第二页的表格
import pandas as pd

# 第二页pdfplumber.Page实例
first_page = pdf.pages[1]

# 自动读取表格信息，返回列表
table = first_page.extract_tables()

# 将列表转为df
table_df = pd.DataFrame(table_2[1:],columns=table_2[0])

table_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c6cb09a5bf84> in <module>
#       9
#      10 # 将列表转为df
# ---> 11 table_df = pd.DataFrame(table_2[1:],columns=table_2[0])
#      12
#      13 table_df
#
# NameError: name 'table_2' is not defined

# %% [markdown]
# pdfplumber提取表格有很多的细节需要处理，这里给到的范例表格线框比较规范，所以能很简单的提取，但对于线框不完全（包含无线框）的表格，其效果就差了不少。
#
# 在实际项目所需处理的pdf文档中，线框完全及不完全的表格都比较多，为了能够理解pdfplumber实现表格抽取的原理和方法，我们需要去细究相关参数的设置。
#
# 正如案例所示，pdfplumber.Page对象的`.extract_table()`方法可以提取表格，返回从页面上最大的表中提取的文本，以列表列表的形式显示，结构为`row -> cell`。
#
# **「表格抽取参数设置」**
#     默认情况下，`extract_table`使用页面的垂直和水平线（或矩形边缘）作为单元格分隔符。该方法可以通过table_settings参数进行高度自定义。可能的设置及其默认值：
#
#  ```python
# {
#     "vertical_strategy": "lines",
#     "horizontal_strategy": "lines",
#     "explicit_vertical_lines": [],
#     "explicit_horizontal_lines": [],
#     "snap_tolerance": 3,
#     "join_tolerance": 3,
#     "edge_min_length": 3,
#     "min_words_vertical": 3,
#     "min_words_horizontal": 1,
#     "keep_blank_chars": False,
#     "text_tolerance": 3,
#     "text_x_tolerance": None,
#     "text_y_tolerance": None,
#     "intersection_tolerance": 3,
#     "intersection_x_tolerance": None,
#     "intersection_y_tolerance": None,
# }
#  ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pdfplumber支持对图表进行可视化调试，能输出图像，显示如何提取表。
